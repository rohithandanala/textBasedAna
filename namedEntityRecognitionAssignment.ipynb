# %% [markdown]
# # Named Entity Recognition
# ## Importing Spacy in English.

# %%
# run the next line only once if needed
#!python -m spacy download en_core_web_lg 
import spacy
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## Getting data from website

# %%
from bs4 import BeautifulSoup
import html5lib
import requests
import re
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))
link1 = url_to_string('https://medium.com/wise-well/the-brain-science-behind-aging-and-forgetting-1954c5c094ab')
link2 = url_to_string('https://medium.com/@timberners_lee/marking-the-webs-35th-birthday-an-open-letter-ebb410cc7d42')
article1 = nlp(link1)
article2 = nlp(link2)
len(article1.ents)
len(article2.ents)
# Out:
# 40

# %% [markdown]
# ## Visualizing NERs

# %%
from spacy import displacy

displacy.render(article1, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Brain Science Behind Aging and Forgetting |
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kathleen Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  | Wise &amp; Well | Mar, 2024 | MediumOpen in appSign upSign inWriteSign upSign inMastodonMember-only storyThe
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brain Science Behind Aging
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ForgettingAre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  younger people smarter? Are older people wiser? Living longer affects the brain, but exactly how may surprise
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     youKathleen Murphy·FollowPublished inWise &amp; Well·5 min
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     read·Mar 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024--60SharePurchased
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  iStock image —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DrAfter123Solomon Shereshevsky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  journalist in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1920s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , was known as “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Man Who Could Not Forget
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .” He could effortlessly recall long lists of numbers or nonsensical information, books of poetry in languages he didn’t know, and complex scientific formulas he never learned.But his superpower came at a price. He was burdened by irrelevant data and struggled to prioritize, filter, and forget what he no longer needed.In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     his later years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , desperate to purge his cluttered mind,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shereshevsky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drank himself to death. His story serves as a cautionary tale about the roles of remembering and forgetting.While we tend to vilify forgetting, everyone forgets, and forgetting plays an essential role in maintaining cognitive health throughout our lifetime, argues
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lisa Genova
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , author of Remember:
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Science of Memory and the Art of Forgetting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# . “An intelligent memory system not only remembers information,” she says, “but also actively forgets whatever is no longer useful.”Pay attention: This is why we forget----60FollowWritten by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kathleen Murphy3.3K Followers·Writer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wise &amp; WellHealth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  writer and essayist offering insights into physical and emotional wellness and successful aging. Subscribe: https://kathleenamurphy.medium.com/subscribeFollowHelpStatusAboutCareersBlogPrivacyTermsText to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speechTeams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  </div></span>

# %%
displacy.render(article2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Marking the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday: An Open Letter | by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Berners-Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  |
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar, 2024 | MediumOpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in appSign upSign inWriteSign upSign inMarking the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday: An Open LetterTim Berners-Lee·Follow5 min
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     read·Mar 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# --151ListenShareOriginal
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HopeThree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a half decades ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when I invented the web, its trajectory was impossible to imagine. There was no roadmap to predict the course of its evolution, it was a captivating odyssey filled with unforeseen opportunities and challenges. Underlying its whole infrastructure was the intention to allow for collaboration, foster compassion and generate creativity — what I term the 3 C’s. It was to be a tool to empower humanity.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The first decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the web fulfilled that promise — the web was decentralised with a long-tail of content and options, it created small, more localised communities, provided individual empowerment and fostered huge value. Yet in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , instead of embodying these values, the web has instead played a part in eroding them. The consequences are increasingly far reaching. From the centralisation of platforms to the AI revolution, the web serves as the foundational layer of our online ecosystem — an ecosystem that is now reshaping the geopolitical landscape, driving economic shifts and influencing the lives of people around the World.State of Affairs5
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when the web turned
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I called out some of the dysfunction caused by the web being dominated by the self-interest of several corporations that have eroded the web’s values and led to breakdown and harm. Now,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on as we arrive at the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday, the rapid advancement of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has exacerbated these concerns, proving that issues on the web are not isolated but rather deeply intertwined with emerging technologies.There are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  clear, connected issues to address. The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  is the extent of power concentration, which contradicts the decentralised spirit I originally envisioned. This has segmented the web, with a fight to keep users hooked on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  platform to optimise profit through the passive observation of content. This exploitative business model is particularly grave in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of elections that could unravel political turmoil. Compounding this issue is the
# <mark class="entity" style="backgroun

# %% [markdown]
# ## Count of each NER

# %%
from collections import Counter
labels1 = [x.label_ for x in article1.ents]
Counter(labels1)
# Out:
# Counter({'PERSON': 7,
#          'ORG': 3,
#          'WORK_OF_ART': 3,
#          'DATE': 3,
#          'LAW': 1,
#          'NORP': 1})

# %%
labels2 = [x.label_ for x in article2.ents]
Counter(labels2)
# Out:
# Counter({'DATE': 11,
#          'ORG': 9,
#          'PERSON': 8,
#          'ORDINAL': 5,
#          'CARDINAL': 2,
#          'GPE': 2,
#          'LAW': 2,
#          'NORP': 1})

# %%
items = [x.text for x in article1.ents]
Counter(items).most_common(5)
# Out:
# [('The Brain Science Behind Aging and Forgetting |', 1),
#  ('Kathleen Murphy', 1),
#  ('Brain Science Behind Aging', 1),
#  ('ForgettingAre', 1),
#  ('youKathleen Murphy·FollowPublished inWise & Well·5 min', 1)]

# %%
items = [x.text for x in article2.ents]
Counter(items).most_common(5)
# Out:
# [('35th', 3),
#  ('Flanders', 2),
#  ('Tim Berners-Lee', 1),
#  ('Mar, 2024 | MediumOpen', 1),
#  ('read·Mar 12', 1)]

# %%
sentences1 = [x for x in article1.sents]
print(sentences1)
# Out:
# [The Brain Science Behind Aging and Forgetting | by Kathleen Murphy | Wise & Well | Mar, 2024 | MediumOpen in appSign upSign inWriteSign upSign inMastodonMember-only storyThe Brain Science Behind Aging and ForgettingAre younger people smarter?, Are older people wiser?, Living longer affects the brain, but exactly how may surprise youKathleen Murphy·FollowPublished inWise & Well·5 min read·Mar 7, 2024--60SharePurchased iStock image — DrAfter123Solomon Shereshevsky, a Russian journalist in the 1920s, was known as “The Man Who Could Not Forget.”, He could effortlessly recall long lists of numbers or nonsensical information, books of poetry in languages he didn’t know, and complex scientific formulas he never learned., But his superpower came at a price., He was burdened by irrelevant data and struggled to prioritize, filter, and forget what he no longer needed., In his later years, desperate to purge his cluttered mind, Shereshevsky drank himself to death., His story serves as a cautionary tale about the roles of remembering and forgetting., While we tend to vilify forgetting, everyone forgets, and forgetting plays an essential role in maintaining cognitive health throughout our lifetime, argues Lisa Genova, author of Remember: The Science of Memory and the Art of Forgetting., “An intelligent memory system not only remembers information,” she says, “but also actively forgets whatever is no longer useful., ”Pay attention:, This is why we forget----60FollowWritten by Kathleen Murphy3.3K Followers·Writer for Wise & WellHealth writer and essayist offering insights into physical and emotional wellness and successful aging., Subscribe:, https://kathleenamurphy.medium.com/subscribeFollowHelpStatusAboutCareersBlogPrivacyTermsText to speechTeams]

# %%
sentences2 = [x for x in article2.sents]
print(sentences2)
# Out:
# [Marking the Web’s 35th Birthday: An Open Letter | by Tim Berners-Lee | Mar, 2024 | MediumOpen in appSign upSign inWriteSign upSign inMarking the Web’s 35th Birthday: An Open LetterTim Berners-Lee·Follow5 min read·Mar 12, 2024--151ListenShareOriginal HopeThree and a half decades ago, when I invented the web, its trajectory was impossible to imagine., There was no roadmap to predict the course of its evolution, it was a captivating odyssey filled with unforeseen opportunities and challenges., Underlying its whole infrastructure was the intention to allow for collaboration, foster compassion and generate creativity — what I term the 3 C’s., It was to be a tool to empower humanity., The first decade of the web fulfilled that promise — the web was decentralised with a long-tail of content and options, it created small, more localised communities, provided individual empowerment and fostered huge value., Yet in the past decade, instead of embodying these values, the web has instead played a part in eroding them., The consequences are increasingly far reaching., From the centralisation of platforms to the AI revolution, the web serves as the foundational layer of our online ecosystem — an ecosystem that is now reshaping the geopolitical landscape, driving economic shifts and influencing the lives of people around the World., State of Affairs5 years ago, when the web turned 30, I called out some of the dysfunction caused by the web being dominated by the self-interest of several corporations that have eroded the web’s values and led to breakdown and harm., Now, 5 years on as we arrive at the Web’s 35th Birthday, the rapid advancement of AI has exacerbated these concerns, proving that issues on the web are not isolated but rather deeply intertwined with emerging technologies., There are two clear, connected issues to address., The first is the extent of power concentration, which contradicts the decentralised spirit I originally envisioned., This has segmented the web, with a fight to keep users hooked on one platform to optimise profit through the passive observation of content., This exploitative business model is particularly grave in this year of elections that could unravel political turmoil., Compounding this issue is the second, the personal data market that has exploited people’s time and data with the creation of deep profiles that allow for targeted advertising and ultimately control over the information people are fed., How has this happened?, Leadership, hindered by a lack of diversity, has steered away from a tool for public good and one that is instead subject to capitalist forces resulting in monopolisation., Governance, which should correct for this, has failed to do so, with regulatory measures being outstripped by the rapid development of innovation, leading to a widening gap between technological advancements and effective oversight., The future hinges on our ability to both reform the current system and create a new one that genuinely serves the best interests of humanity., To achieve this, we must break down data silos to encourage collaboration, create market conditions in which a diversity of options thrive to fuel creativity, and shift away from polarising content to an environment shaped by a diversity of voices and perspectives that nurture empathy and understanding., Level SetTo truly transform the current system, we must simultaneously tackle its existing problems and champion the efforts of those visionary individuals who are actively working to build a new, improved system., A new paradigm is emerging, one that places individuals’ intention rather than attention at the heart of business models, freeing us from the constraints of the established order and returning control over our data., Driven by a new generation of pioneers, this movement seeks to create a more human-centred web, aligned with my original vision., These innovators hail from diverse disciplines — research, policy, and product design — uni ...

# %%
displacy.render(nlp(str(sentences1)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Brain Science Behind Aging and Forgetting |
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kathleen Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  | Wise &amp; Well | Mar, 2024 | MediumOpen in appSign upSign inWriteSign upSign inMastodonMember-only storyThe
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brain Science Behind Aging
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ForgettingAre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  younger people smarter?, Are older people wiser?, Living longer affects the brain, but exactly how may surprise
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     youKathleen Murphy·FollowPublished inWise &amp; Well·5 min
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     read·Mar 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024--60SharePurchased
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  iStock image —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DrAfter123Solomon Shereshevsky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  journalist in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1920s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , was known as “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Man Who Could Not Forget
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# .”, He could effortlessly recall long lists of numbers or nonsensical information, books of poetry in languages he didn’t know, and complex scientific formulas he never learned., But his superpower came at a price., He was burdened by irrelevant data and struggled to prioritize, filter, and forget what he no longer needed., In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     his later years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , desperate to purge his cluttered mind,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shereshevsky
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  drank himself to death., His story serves as a cautionary tale about the roles of remembering and forgetting., While we tend to vilify forgetting, everyone forgets, and forgetting plays an essential role in maintaining cognitive health throughout our lifetime, argues
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lisa Genova
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , author of Remember:
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Science of Memory and the Art of Forgetting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ., “An intelligent memory system not only remembers information,” she says, “but also actively forgets whatever is no longer useful., ”Pay attention:, This is why we forget----60FollowWritten by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kathleen Murphy3.3K Followers·Writer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wise &amp; WellHealth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  writer and essayist offering insights into physical and emotional wellness and successful aging., Subscribe:, https://kathleenamurphy.medium.com/subscribeFollowHelpStatusAboutCareersBlogPrivacyTermsText to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     speechTeams
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ]</div></span>

# %%
displacy.render(nlp(str(sentences2)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[Marking the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday: An Open Letter | by
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tim Berners-Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  |
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mar, 2024 | MediumOpen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in appSign upSign inWriteSign upSign inMarking the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday: An Open LetterTim Berners-Lee·Follow5 min
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     read·Mar 12
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# --151ListenShareOriginal
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HopeThree
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a half decades ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when I invented the web, its trajectory was impossible to imagine., There was no roadmap to predict the course of its evolution, it was a captivating odyssey filled with unforeseen opportunities and challenges., Underlying its whole infrastructure was the intention to allow for collaboration, foster compassion and generate creativity — what I term the 3 C’s., It was to be a tool to empower humanity.,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The first decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the web fulfilled that promise — the web was decentralised with a long-tail of content and options, it created small, more localised communities, provided individual empowerment and fostered huge value., Yet in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , instead of embodying these values, the web has instead played a part in eroding them., The consequences are increasingly far reaching., From the centralisation of platforms to the AI revolution, the web serves as the foundational layer of our online ecosystem — an ecosystem that is now reshaping the geopolitical landscape, driving economic shifts and influencing the lives of people around the World.,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     State
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of Affairs5
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     years ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when the web turned
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I called out some of the dysfunction caused by the web being dominated by the self-interest of several corporations that have eroded the web’s values and led to breakdown and harm., Now,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  on as we arrive at the Web’s
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     35th
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  Birthday, the rapid advancement of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has exacerbated these concerns, proving that issues on the web are not isolated but rather deeply intertwined with emerging technologies., There are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  clear, connected issues to address., The
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  is the extent of power concentration, which contradicts the decentralised spirit I originally envisioned., This has segmented the web, with a fight to keep users hooked on
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  platform to optimise profit through the passive observation of content., This exploitative business model is particularly grave in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-

# %% [markdown]
# ## Type of words in the sentence

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences1)) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Brain', 'PROPN', 'Brain'),
#  ('Science', 'PROPN', 'Science'),
#  ('Aging', 'NOUN', 'aging'),
#  ('Forgetting', 'VERB', 'forget'),
#  ('|', 'VERB', '|'),
#  ('Kathleen', 'PROPN', 'Kathleen'),
#  ('Murphy', 'PROPN', 'Murphy'),
#  ('|', 'VERB', '|'),
#  ('Wise', 'PROPN', 'Wise'),
#  ('&', 'CCONJ', '&'),
#  ('Mar', 'PROPN', 'Mar'),
#  ('2024', 'NUM', '2024'),
#  ('|', 'SYM', '|'),
#  ('MediumOpen', 'PROPN', 'MediumOpen'),
#  ('appSign', 'NOUN', 'appsign'),
#  ('upSign', 'ADJ', 'upsign'),
#  ('inWriteSign', 'PROPN', 'inWriteSign'),
#  ('upSign', 'ADJ', 'upsign'),
#  ('inMastodonMember', 'X', 'inmastodonmember'),
#  ('storyThe', 'DET', 'storythe'),
#  ('Brain', 'PROPN', 'Brain'),
#  ('Science', 'PROPN', 'Science'),
#  ('Aging', 'NOUN', 'aging'),
#  ('ForgettingAre', 'PROPN', 'ForgettingAre'),
#  ('younger', 'ADJ', 'young'),
#  ('people', 'NOUN', 'people'),
#  ('smarter', 'ADJ', 'smart'),
#  ('older', 'ADJ', 'old'),
#  ('people', 'NOUN', 'people'),
#  ('wiser', 'ADJ', 'wise'),
#  ('Living', 'NOUN', 'living'),
#  ('longer', 'ADV', 'long'),
#  ('affects', 'VERB', 'affect'),
#  ('brain', 'NOUN', 'brain'),
#  ('exactly', 'ADV', 'exactly'),
#  ('surprise', 'VERB', 'surprise'),
#  ('youKathleen', 'PROPN', 'youKathleen'),
#  ('Murphy·FollowPublished', 'X', 'murphy·followpublished'),
#  ('inWise', 'X', 'inwise'),
#  ('&', 'CCONJ', '&'),
#  ('Well·5', 'PROPN', 'Well·5'),
#  ('min', 'PROPN', 'min'),
#  ('read·Mar', 'PROPN', 'read·Mar'),
#  ('7', 'NUM', '7'),
#  ('2024', 'NUM', '2024'),
#  ('-60SharePurchased', 'VERB', '-60sharepurchase'),
#  ('iStock', 'PROPN', 'iStock'),
#  ('image', 'NOUN', 'image'),
#  ('DrAfter123Solomon', 'PROPN', 'DrAfter123Solomon'),
#  ('Shereshevsky', 'PROPN', 'Shereshevsky'),
#  ('Russian', 'ADJ', 'russian'),
#  ('journalist', 'NOUN', 'journalist'),
#  ('1920s', 'NUM', '1920s'),
#  ('known', 'VERB', 'know'),
#  ('Man', 'PROPN', 'Man'),
#  ('Forget', 'VERB', 'forget'),
#  ('effortlessly', 'ADV', 'effortlessly'),
#  ('recall', 'VERB', 'recall'),
#  ('long', 'ADJ', 'long'),
#  ('lists', 'NOUN', 'list'),
#  ('numbers', 'NOUN', 'number'),
#  ('nonsensical', 'ADJ', 'nonsensical'),
#  ('information', 'NOUN', 'information'),
#  ('books', 'NOUN', 'book'),
#  ('poetry', 'NOUN', 'poetry'),
#  ('languages', 'NOUN', 'language'),
#  ('know', 'VERB', 'know'),
#  ('complex', 'ADJ', 'complex'),
#  ('scientific', 'ADJ', 'scientific'),
#  ('formulas', 'NOUN', 'formula'),
#  ('learned', 'VERB', 'learn'),
#  ('superpower', 'NOUN', 'superpower'),
#  ('came', 'VERB', 'come'),
#  ('price', 'NOUN', 'price'),
#  ('burdened', 'VERB', 'burden'),
#  ('irrelevant', 'ADJ', 'irrelevant'),
#  ('data', 'NOUN', 'datum'),
#  ('struggled', 'VERB', 'struggle'),
#  ('prioritize', 'VERB', 'prioritize'),
#  ('filter', 'NOUN', 'filter'),
#  ('forget', 'VERB', 'forget'),
#  ('longer', 'ADV', 'long'),
#  ('needed', 'VERB', 'need'),
#  ('later', 'ADJ', 'later'),
#  ('years', 'NOUN', 'year'),
#  ('desperate', 'ADJ', 'desperate'),
#  ('purge', 'VERB', 'purge'),
#  ('cluttered', 'ADJ', 'cluttered'),
#  ('mind', 'NOUN', 'mind'),
#  ('Shereshevsky', 'PROPN', 'Shereshevsky'),
#  ('drank', 'VERB', 'drink'),
#  ('death', 'NOUN', 'death'),
#  ('story', 'NOUN', 'story'),
#  ('serves', 'VERB', 'serve'),
#  ('cautionary', 'ADJ', 'cautionary'),
#  ('tale', 'NOUN', 'tale'),
#  ('roles', 'NOUN', 'role'),
#  ('remembering', 'VERB', 'remember'),
#  ('forgetting', 'NOUN', 'forgetting'),
#  ('tend', 'VERB', 'tend'),
#  ('vilify', 'VERB', 'vilify'),
#  ('forgetting', 'VERB', 'forget'),
#  ('forgets', 'VERB', 'forget'),
#  ('forgetting', 'VERB', 'forget'),
#  ('plays', 'VERB', 'play'),
#  ('essential', 'ADJ', 'essential'),
#  ('role', 'NOUN', 'role'),
#  ('maintaining', 'VERB', 'maintain'),
#  ('cognitive', 'ADJ', 'cognitive'),
#  ('health', 'NOUN', 'health'),
#  ('lifetime', 'NOUN', 'lifetime'),
#  ('argues', 'VERB', 'argue'),
#  ('Lisa', 'PROPN', 'Lisa'),
#  ('Genova', 'PROPN', 'Genova'),
#  ('author', 'NOUN', 'author'),
#  ('Remember', 'PROPN', 'Remember'),
#  ('Science', 'PROPN', 'Science'),
#  ('Memory', 'PROPN', 'Memory'),
#  ('Art', 'NOUN', 'art'),
#  ('Forgetting', 'PROPN', 'Forgetting'),
#  ('intelligent', 'ADJ', 'intelligent'),
#  ('memory', 'NOUN', 'memory'),
#  ('system', 'NOUN', 'system'),
#  ('remembers', 'VERB', 'remember'),
#  ('information', 'NOUN', 'information'),
#  ('says', 'VERB', 'say'),
#  ('actively', 'ADV', 'actively'),
#  ('forgets', 'VERB', 'forget'),
#  ('longer', 'ADV', 'long'),
#  ('useful', 'ADJ', 'useful'),
#  ('Pay', 'VERB', 'pay'),
#  ('attention', 'NOUN', 'attention'),
#  ('forget----60FollowWritten', 'VERB', 'forget----60followwritten'),
#  ('Kathleen', 'PROPN', 'Kathleen'),
#  ('K', 'NOUN', 'k'),
#  ('Followers·Writer', 'NOUN', 'followers·writer'),
#  ('Wise', 'PROPN', 'Wise'),
#  ('&', 'CCONJ', '&'),
#  ('WellHealth', 'PROPN', 'WellHealth'),
#  ('writer', 'NOUN', 'writer'),
#  ('essayist', 'NOUN', 'essayist'),
#  ('offering', 'VERB', 'offer'),
#  ('insights', 'NOUN', 'insight'),
#  ('physical', 'ADJ', 'physical'),
#  ('emotional', 'ADJ', 'emotional'),
#  ('wellness', 'NOUN', 'wellness'),
#  ('successful', 'ADJ', 'successful'),
#  ('aging', 'NOUN', 'aging'),
#  ('Subscribe', 'VERB', 'subscribe'),
#  ('https://kathleenamurphy.medium.com/subscribeFollowHelpStatusAboutCareersBlogPrivacyTermsText',
#   'NOUN',
#   'https://kathleenamurphy.medium.com/subscribefollowhelpstatusaboutcareersblogprivacytermstext'),
#  ('speechTeams', 'NUM', 'speechteams')]

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences2)) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('[', 'X', '['),
#  ('Marking', 'VERB', 'mark'),
#  ('Web', 'NOUN', 'web'),
#  ('35th', 'ADJ', '35th'),
#  ('Birthday', 'NOUN', 'birthday'),
#  ('Open', 'ADJ', 'open'),
#  ('Letter', 'PROPN', 'Letter'),
#  ('|', 'VERB', '|'),
#  ('Tim', 'PROPN', 'Tim'),
#  ('Berners', 'PROPN', 'Berners'),
#  ('Lee', 'PROPN', 'Lee'),
#  ('|', 'VERB', '|'),
#  ('Mar', 'PROPN', 'Mar'),
#  ('2024', 'NUM', '2024'),
#  ('|', 'SYM', '|'),
#  ('MediumOpen', 'PROPN', 'MediumOpen'),
#  ('appSign', 'NOUN', 'appsign'),
#  ('upSign', 'ADJ', 'upsign'),
#  ('inWriteSign', 'PROPN', 'inWriteSign'),
#  ('upSign', 'ADJ', 'upsign'),
#  ('inMarking', 'VERB', 'inmarke'),
#  ('Web', 'NOUN', 'web'),
#  ('35th', 'ADJ', '35th'),
#  ('Birthday', 'NOUN', 'birthday'),
#  ('Open', 'ADJ', 'open'),
#  ('LetterTim', 'NOUN', 'lettertim'),
#  ('Berners', 'PROPN', 'Berners'),
#  ('Lee·Follow5', 'PROPN', 'Lee·Follow5'),
#  ('min', 'PROPN', 'min'),
#  ('read·Mar', 'PROPN', 'read·Mar'),
#  ('12', 'NUM', '12'),
#  ('2024', 'NUM', '2024'),
#  ('-151ListenShareOriginal', 'ADJ', '-151listenshareoriginal'),
#  ('HopeThree', 'PROPN', 'HopeThree'),
#  ('half', 'NOUN', 'half'),
#  ('decades', 'NOUN', 'decade'),
#  ('ago', 'ADV', 'ago'),
#  ('invented', 'VERB', 'invent'),
#  ('web', 'NOUN', 'web'),
#  ('trajectory', 'NOUN', 'trajectory'),
#  ('impossible', 'ADJ', 'impossible'),
#  ('imagine', 'VERB', 'imagine'),
#  ('roadmap', 'NOUN', 'roadmap'),
#  ('predict', 'VERB', 'predict'),
#  ('course', 'NOUN', 'course'),
#  ('evolution', 'NOUN', 'evolution'),
#  ('captivating', 'ADJ', 'captivating'),
#  ('odyssey', 'NOUN', 'odyssey'),
#  ('filled', 'VERB', 'fill'),
#  ('unforeseen', 'ADJ', 'unforeseen'),
#  ('opportunities', 'NOUN', 'opportunity'),
#  ('challenges', 'NOUN', 'challenge'),
#  ('Underlying', 'VERB', 'underlie'),
#  ('infrastructure', 'NOUN', 'infrastructure'),
#  ('intention', 'NOUN', 'intention'),
#  ('allow', 'VERB', 'allow'),
#  ('collaboration', 'NOUN', 'collaboration'),
#  ('foster', 'ADJ', 'foster'),
#  ('compassion', 'NOUN', 'compassion'),
#  ('generate', 'VERB', 'generate'),
#  ('creativity', 'NOUN', 'creativity'),
#  ('term', 'VERB', 'term'),
#  ('3', 'NUM', '3'),
#  ('C', 'NOUN', 'c'),
#  ('tool', 'NOUN', 'tool'),
#  ('empower', 'VERB', 'empower'),
#  ('humanity', 'NOUN', 'humanity'),
#  ('decade', 'NOUN', 'decade'),
#  ('web', 'NOUN', 'web'),
#  ('fulfilled', 'VERB', 'fulfil'),
#  ('promise', 'NOUN', 'promise'),
#  ('web', 'NOUN', 'web'),
#  ('decentralised', 'VERB', 'decentralise'),
#  ('long', 'ADJ', 'long'),
#  ('tail', 'NOUN', 'tail'),
#  ('content', 'NOUN', 'content'),
#  ('options', 'NOUN', 'option'),
#  ('created', 'VERB', 'create'),
#  ('small', 'ADJ', 'small'),
#  ('localised', 'VERB', 'localise'),
#  ('communities', 'NOUN', 'community'),
#  ('provided', 'VERB', 'provide'),
#  ('individual', 'ADJ', 'individual'),
#  ('empowerment', 'NOUN', 'empowerment'),
#  ('fostered', 'VERB', 'foster'),
#  ('huge', 'ADJ', 'huge'),
#  ('value', 'NOUN', 'value'),
#  ('past', 'ADJ', 'past'),
#  ('decade', 'NOUN', 'decade'),
#  ('instead', 'ADV', 'instead'),
#  ('embodying', 'VERB', 'embody'),
#  ('values', 'NOUN', 'value'),
#  ('web', 'NOUN', 'web'),
#  ('instead', 'ADV', 'instead'),
#  ('played', 'VERB', 'play'),
#  ('eroding', 'VERB', 'erode'),
#  ('consequences', 'NOUN', 'consequence'),
#  ('increasingly', 'ADV', 'increasingly'),
#  ('far', 'ADV', 'far'),
#  ('reaching', 'VERB', 'reach'),
#  ('centralisation', 'NOUN', 'centralisation'),
#  ('platforms', 'NOUN', 'platform'),
#  ('AI', 'PROPN', 'AI'),
#  ('revolution', 'NOUN', 'revolution'),
#  ('web', 'NOUN', 'web'),
#  ('serves', 'VERB', 'serve'),
#  ('foundational', 'ADJ', 'foundational'),
#  ('layer', 'NOUN', 'layer'),
#  ('online', 'ADJ', 'online'),
#  ('ecosystem', 'NOUN', 'ecosystem'),
#  ('ecosystem', 'NOUN', 'ecosystem'),
#  ('reshaping', 'VERB', 'reshape'),
#  ('geopolitical', 'ADJ', 'geopolitical'),
#  ('landscape', 'NOUN', 'landscape'),
#  ('driving', 'VERB', 'drive'),
#  ('economic', 'ADJ', 'economic'),
#  ('shifts', 'NOUN', 'shift'),
#  ('influencing', 'VERB', 'influence'),
#  ('lives', 'NOUN', 'life'),
#  ('people', 'NOUN', 'people'),
#  ('World', 'PROPN', 'World'),
#  ('State', 'NOUN', 'state'),
#  ('Affairs5', 'PROPN', 'Affairs5'),
#  ('years', 'NOUN', 'year'),
#  ('ago', 'ADV', 'ago'),
#  ('web', 'NOUN', 'web'),
#  ('turned', 'VERB', 'turn'),
#  ('30', 'NUM', '30'),
#  ('called', 'VERB', 'call'),
#  ('dysfunction', 'NOUN', 'dysfunction'),
#  ('caused', 'VERB', 'cause'),
#  ('web', 'NOUN', 'web'),
#  ('dominated', 'VERB', 'dominate'),
#  ('self', 'NOUN', 'self'),
#  ('interest', 'NOUN', 'interest'),
#  ('corporations', 'NOUN', 'corporation'),
#  ('eroded', 'VERB', 'erode'),
#  ('web', 'NOUN', 'web'),
#  ('values', 'NOUN', 'value'),
#  ('led', 'VERB', 'lead'),
#  ('breakdown', 'NOUN', 'breakdown'),
#  ('harm', 'NOUN', 'harm'),
#  ('5', 'NUM', '5'),
#  ('years', 'NOUN', 'year'),
#  ('arrive', 'VERB', 'arrive'),
#  ('Web', 'NOUN', 'web'),
#  ('35th', 'ADJ', '35th'),
#  ('Birthday', 'NOUN', 'birthday'),
#  ('rapid', 'ADJ', 'rapid'),
#  ('advancement', 'NOUN', 'advancement'),
#  ('AI', 'PROPN', 'AI'),
#  ('exacerbated', 'VERB', 'exacerbate'),
#  ('concerns', 'NOUN', 'concern'),
#  ('proving', 'VERB', 'prove'),
#  ('issues', 'NOUN', 'issue'),
#  ('web', 'NOUN', 'web'),
#  ('isolated', 'ADJ', 'isolated'),
#  ('deeply', 'ADV', 'deeply'),
#  ('intertwined', 'VERB', 'intertwine'),
#  ('emerging', 'VERB', 'emerge'),
#  ('technologies', 'NOUN', 'technology'),
#  ('clear', 'ADJ', 'clear'),
#  ('connected', 'ADJ', 'connected'),
#  ('issues', 'NOUN', 'issue'),
#  ('address', 'VERB', 'address'),
#  ('extent', 'NOUN', 'extent'),
#  ('power', 'NOUN', 'power'),
#  ('concentration', 'NOUN', 'concentration'),
#  ('contradicts', 'VERB', 'contradict'),
#  ('decentralised', 'ADJ', 'decentralised'),
#  ('spirit', 'NOUN', 'spirit'),
#  ('originally', 'ADV', 'originally'),
#  ('envisioned', 'VERB', 'envision'),
#  ('segmented', 'VERB', 'segment'),
#  ('web', 'NOUN', 'web'),
#  ('fight', 'NOUN', 'fight'),
#  ('users', 'NOUN', 'user'),
#  ('hooked', 'VERB', 'hook'),
#  ('platform', 'NOUN', 'platform'),
#  ('optimise', 'VERB', 'optimise'),
#  ('profit', 'NOUN', 'profit'),
#  ('passive', 'ADJ', 'passive'),
#  ('observation', 'NOUN', 'observation'),
#  ('content', 'NOUN', 'content'),
#  ('exploitative', 'ADJ', 'exploitative'),
#  ('business', 'NOUN', 'business'),
#  ('model', 'NOUN', 'model'),
#  ('particularly', 'ADV', 'particularly'),
#  ('grave', 'ADJ', 'grave'),
#  ('year', 'NOUN', 'year'),
#  ('elections', 'NOUN', 'election'),
#  ('unravel', 'VERB', 'unravel'),
#  ('political', 'ADJ', 'political'),
#  ('turmoil', 'NOUN', 'turmoil'),
#  ('Compounding', 'VERB', 'compound'),
#  ('issue', 'NOUN', 'issue'),
#  ('second', 'ADJ', 'second'),
#  ('personal', 'ADJ', 'personal'),
#  ('data', 'NOUN', 'data'),
#  ('market', 'NOUN', 'market'),
#  ('exploited', 'VERB', 'exploit'),
#  ('people', 'NOUN', 'people'),
#  ('time', 'NOUN', 'time'),
#  ('data', 'NOUN', 'datum'),
#  ('creation', 'NOUN', 'creation'),
#  ('deep', 'ADJ', 'deep'),
#  ('profiles', 'NOUN', 'profile'),
#  ('allow', 'VERB', 'allow'),
#  ('targeted', 'VERB', 'target'),
#  ('advertising', 'NOUN', 'advertising'),
#  ('ultimately', 'ADV', 'ultimately'),
#  ('control', 'VERB', 'control'),
#  ('information', 'NOUN', 'information'),
#  ('people', 'NOUN', 'people'),
#  ('fed', 'VERB', 'feed'),
#  ('happened', 'VERB', 'happen'),
#  ('Leadership', 'PROPN', 'Leadership'),
#  ('hindered', 'VERB', 'hinder'),
#  ('lack', 'NOUN', 'lack'),
#  ('diversity', 'NOUN', 'diversity'),
#  ('steered', 'VERB', 'steer'),
#  ('away', 'ADV', 'away'),
#  ('tool', 'NOUN', 'tool'),
#  ('public', 'ADJ', 'public'),
#  ('good', 'NOUN', 'good'),
#  ('instead', 'ADV', 'instead'),
#  ('subject', 'ADJ', 'subject'),
#  ('capitalist', 'ADJ', 'capitalist'),
#  ('forces', 'NOUN', 'force'),
#  ('resulting', 'VERB', 'result'),
#  ('monopolisation', 'NOUN', 'monopolisation'),
#  ('Governance', 'PROPN', 'Governance'),
#  ('correct', 'VERB', 'correct'),
#  ('failed', 'VERB', 'fail'),
#  ('regulatory', 'ADJ', 'regulatory'),
#  ('measures', 'NOUN', 'measure'),
#  ('outstripped', 'VERB', 'outstrip'),
#  ('rapid', 'ADJ', 'rapid'),
#  ('development', 'NOUN', 'development'),
#  ('innovation', 'NOUN', 'innovation'),
#  ('leading', 'VERB', 'lead'),
#  ('widening', 'VERB', 'widen'),
#  ('gap', 'NOUN', 'gap'),
#  ('technological', 'ADJ', 'technological'),
#  ('advancements', 'NOUN', 'advancement'),
#  ('effective', 'ADJ', 'effective'),
#  ('oversight', 'NOUN', 'oversight'),
#  ('future', 'ADJ', 'future'),
#  ('hinges', 'VERB', 'hinge'),
#  ('ability', 'NOUN', 'ability'),
#  ('reform', 'VERB', 'reform'),
#  ('current', 'ADJ', 'current'),
#  ('system', 'NOUN', 'system'),
#  ('create', 'VERB', 'create'),
#  ('new', 'ADJ', 'new'),
#  ('genuinely', 'ADV', 'genuinely'),
#  ('serves', 'VERB', 'serve'),
#  ('best', 'ADJ', 'good'),
#  ('interests', 'NOUN', 'interest'),
#  ('humanity', 'NOUN', 'humanity'),
#  ('achieve', 'VERB', 'achieve'),
#  ('break', 'VERB', 'break'),
#  ('data', 'NOUN', 'data'),
#  ('silos', 'NOUN', 'silo'),
#  ('encourage', 'VERB', 'encourage'),
#  ('collaboration', 'NOUN', 'collaboration'),
#  ('create', 'VERB', 'create'),
#  ('market', 'NOUN', 'market'),
#  ('conditions', 'NOUN', 'condition'),
#  ('diversity', 'NOUN', 'diversity'),
#  ('options', 'NOUN', 'option'),
#  ('thrive', 'VERB', 'thrive'),
#  ('fuel', 'NOUN', 'fuel'),
#  ('creativity', 'NOUN', 'creativity'),
#  ('shift', 'VERB', 'shift'),
#  ('away', 'ADV', 'away'),
#  ('polarising', 'VERB', 'polarise'),
#  ('content', 'NOUN', 'content'),
#  ('environment', 'NOUN', 'environment'),
#  ('shaped', 'VERB', 'shape'),
#  ('diversity', 'NOUN', 'diversity'),
#  ('voices', 'NOUN', 'voice'),
#  ('perspectives', 'NOUN', 'perspective'),
#  ('nurture', 'VERB', 'nurture'),
#  ('empathy', 'NOUN', 'empathy'),
#  ('understanding', 'NOUN', 'understanding'),
#  ('Level', 'NOUN', 'level'),
#  ('SetTo', 'PROPN', 'SetTo'),
#  ('truly', 'ADV', 'truly'),
#  ('transform', 'VERB', 'transform'),
#  ('current', 'ADJ', 'current'),
#  ('system', 'NOUN', 'system'),
#  ('simultaneously', 'ADV', 'simultaneously'),
#  ('tackle', 'VERB', 'tackle'),
#  ('existing', 'VERB', 'exist'),
#  ('problems', 'NOUN', 'problem'),
#  ('champion', 'VERB', 'champion'),
#  ('efforts', 'NOUN', 'effort'),
#  ('visionary', 'ADJ', 'visionary'),
#  ('individuals', 'NOUN', 'individual'),
#  ('actively', 'ADV', 'actively'),
#  ('working', 'VERB', 'work'),
#  ('build', 'VERB', 'build'),
#  ('new', 'ADJ', 'new'),
#  ('improved', 'ADJ', 'improved'),
#  ('system', 'NOUN', 'system'),
#  ('new', 'ADJ', 'new'),
#  ('paradigm', 'NOUN', 'paradigm'),
#  ('emerging', 'VERB', 'emerge'),
#  ('places', 'VERB', 'place'),
#  ('individuals', 'NOUN', 'individual'),
#  ('’', 'PART', '’'),
#  ('intention', 'NOUN', 'intention'),
#  ('attention', 'NOUN', 'attention'),
#  ('heart', 'NOUN', 'heart'),
#  ('business', 'NOUN', 'business'),
#  ('models', 'NOUN', 'model'),
#  ('freeing', 'VERB', 'free'),
#  ('constraints', 'NOUN', 'constraint'),
#  ('established', 'VERB', 'establish'),
#  ('order', 'NOUN', 'order'),
#  ('returning', 'VERB', 'return'),
#  ('control', 'NOUN', 'control'),
#  ('data', 'NOUN', 'datum'),
#  ('Driven', 'VERB', 'drive'),
#  ('new', 'ADJ', 'new'),
#  ('generation', 'NOUN', 'generation'),
#  ('pioneers', 'NOUN', 'pioneer'),
#  ('movement', 'NOUN', 'movement'),
#  ('seeks', 'VERB', 'seek'),
#  ('create', 'VERB', 'create'),
#  ('human', 'ADJ', 'human'),
#  ('centred', 'VERB', 'centre'),
#  ('web', 'NOUN', 'web'),
#  ('aligned', 'VERB', 'align'),
#  ('original', 'ADJ', 'original'),
#  ('vision', 'NOUN', 'vision'),
#  ('innovators', 'NOUN', 'innovator'),
#  ('hail', 'VERB', 'hail'),
#  ('diverse', 'ADJ', 'diverse'),
#  ('disciplines', 'NOUN', 'discipline'),
#  ('research', 'NOUN', 'research'),
#  ('policy', 'NOUN', 'policy'),
#  ('product', 'NOUN', 'product'),
#  ('design', 'NOUN', 'design'),
#  ('united', 'VERB', 'unite'),
#  ('pursuit', 'NOUN', 'pursuit'),
#  ('web', 'NOUN', 'web'),
#  ('related', 'ADJ', 'related'),
#  ('technologies', 'NOUN', 'technology'),
#  ('serve', 'VERB', 'serve'),
#  ('empower', 'VERB', 'empower'),
#  ('Bluesky', 'PROPN', 'Bluesky'),
#  ('Mastadon', 'PROPN', 'Mastadon'),
#  ('feed', 'VERB', 'feed'),
#  ('engagement', 'NOUN', 'engagement'),
#  ('create', 'VERB', 'create'),
#  ('group', 'NOUN', 'group'),
#  ('formation', 'NOUN', 'formation'),
#  ('Github', 'PROPN', 'Github'),
#  ('provides', 'VERB', 'provide'),
#  ('online', 'ADJ', 'online'),
#  ('collaboration', 'NOUN', 'collaboration'),
#  ('tools', 'NOUN', 'tool'),
#  ('podcasts', 'NOUN', 'podcast'),
#  ('contribute', 'VERB', 'contribute'),
#  ('community', 'NOUN', 'community'),
#  ('knowledge', 'NOUN', 'knowledge'),
#  ('emergent', 'ADJ', 'emergent'),
#  ('paradigm', 'NOUN', 'paradigm'),
#  ('gains', 'VERB', 'gain'),
#  ('momentum', 'NOUN', 'momentum'),
#  ('opportunity', 'NOUN', 'opportunity'),
#  ('-', 'VERB', '-'),
#  ('shape', 'VERB', 'shape'),
#  ('digital', 'ADJ', 'digital'),
#  ('future', 'NOUN', 'future'),
#  ('prioritises', 'VERB', 'prioritise'),
#  ('human', 'ADJ', 'human'),
#  ('equity', 'NOUN', 'equity'),
#  ('autonomy', 'NOUN', 'autonomy'),
#  ('time', 'NOUN', 'time'),
#  ('act', 'VERB', 'act'),
#  ('embrace', 'VERB', 'embrace'),
#  ('transformative', 'ADJ', 'transformative'),
#  ('potential', 'NOUN', 'potential'),
#  ('Fundamental', 'ADJ', 'fundamental'),
#  ('ChangeAs', 'PROPN', 'ChangeAs'),
#  ('outlined', 'VERB', 'outline'),
#  ('Contract', 'PROPN', 'Contract'),
#  ('Web', 'NOUN', 'web'),
#  ('multitude', 'NOUN', 'multitude'),
#  ('stakeholders', 'NOUN', 'stakeholder'),
#  ('collaborate', 'VERB', 'collaborate'),
#  ('reform', 'VERB', 'reform'),
#  ('web', 'NOUN', 'web'),
#  ('guide', 'VERB', 'guide'),
#  ('development', 'NOUN', 'development'),
#  ('emerging', 'VERB', 'emerge'),
#  ('technologies', 'NOUN', 'technology'),
#  ('Innovative', 'ADJ', 'innovative'),
#  ('market', 'NOUN', 'market'),
#  ('solutions', 'NOUN', 'solution'),
#  ('like', 'ADP', 'like'),
#  ('highlighted', 'VERB', 'highlight'),
#  ('essential', 'ADJ', 'essential'),
#  ('process', 'NOUN', 'process'),
#  ('Forward', 'PROPN', 'Forward'),
#  ('thinking', 'VERB', 'think'),
#  ('legislation', 'NOUN', 'legislation'),
#  ('governments', 'NOUN', 'government'),
#  ('worldwide', 'ADV', 'worldwide'),
#  ('facilitate', 'VERB', 'facilitate'),
#  ('solutions', 'NOUN', 'solution'),
#  ('help', 'VERB', 'help'),
#  ('manage', 'VERB', 'manage'),
#  ('current', 'ADJ', 'current'),
#  ('system', 'NOUN', 'system'),
#  ('effectively', 'ADV', 'effectively'),
#  ('Finally', 'ADV', 'finally'),
#  ('citizens', 'NOUN', 'citizen'),
#  ('world', 'NOUN', 'world'),
#  ('need', 'VERB', 'need'),
#  ('engaged', 'VERB', 'engage'),
#  ('demand', 'VERB', 'demand'),
#  ('higher', 'ADJ', 'high'),
#  ('standards', 'NOUN', 'standard'),
#  ('greater', 'ADJ', 'great'),
#  ('accountability', 'NOUN', 'accountability'),
#  ('online', 'ADJ', 'online'),
#  ('experiences', 'NOUN', 'experience'),
#  ('time', 'NOUN', 'time'),
#  ('confront', 'VERB', 'confront'),
#  ('dominant', 'ADJ', 'dominant'),
#  ('system', 'NOUN', 'system'),
#  ('shortcomings', 'NOUN', 'shortcoming'),
#  ('catalysing', 'VERB', 'catalyse'),
#  ('transformative', 'ADJ', 'transformative'),
#  ('solutions', 'NOUN', 'solution'),
#  ('empower', 'VERB', 'empower'),
#  ('individuals', 'NOUN', 'individual'),
#  ('emergent', 'ADJ', 'emergent'),
#  ('system', 'NOUN', 'system'),
#  ('ripe', 'ADJ', 'ripe'),
#  ('potential', 'NOUN', 'potential'),
#  ('rising', 'VERB', 'rise'),
#  ('tools', 'NOUN', 'tool'),
#  ('control', 'NOUN', 'control'),
#  ('reach', 'NOUN', 'reach'),
#  ('solution', 'NOUN', 'solution'),
#  ('Solid', 'PROPN', 'Solid'),
#  ('Protocol', 'PROPN', 'Protocol'),
#  ('specification', 'NOUN', 'specification'),
#  ('movement', 'NOUN', 'movement'),
#  ('provide', 'VERB', 'provide'),
#  ('person', 'NOUN', 'person'),
#  ('personal', 'ADJ', 'personal'),
#  ('online', 'ADJ', 'online'),
#  ('data', 'NOUN', 'datum'),
#  ('store', 'NOUN', 'store'),
#  ('known', 'VERB', 'know'),
#  ('POD', 'PROPN', 'POD'),
#  ('.', 'PROPN', '.'),
#  ('return', 'VERB', 'return'),
#  ('value', 'NOUN', 'value'),
#  ('lost', 'VERB', 'lose'),
#  ('restore', 'VERB', 'restore'),
#  ('control', 'NOUN', 'control'),
#  ('personal', 'ADJ', 'personal'),
#  ('data', 'NOUN', 'datum'),
#  ('Solid', 'PROPN', 'Solid'),
#  ('individuals', 'NOUN', 'individual'),
#  ('decide', 'VERB', 'decide'),
#  ('data', 'NOUN', 'datum'),
#  ('managed', 'VERB', 'manage'),
#  ('shared', 'VERB', 'share'),
#  ('approach', 'NOUN', 'approach'),
#  ('begun', 'VERB', 'begin'),
#  ('root', 'NOUN', 'root'),
#  ('seen', 'VERB', 'see'),
#  ('Flanders', 'PROPN', 'Flanders'),
#  ('citizen', 'NOUN', 'citizen'),
#  ('POD', 'PROPN', 'POD'),
#  ('Jan', 'PROPN', 'Jan'),
#  ('Jambon', 'PROPN', 'Jambon'),
#  ('announced', 'VERB', 'announce'),
#  ('years', 'NOUN', 'year'),
#  ('ago', 'ADV', 'ago'),
#  ('Flanders', 'PROPN', 'Flanders'),
#  ('citizens', 'NOUN', 'citizen'),
#  ('POD', 'PROPN', 'POD'),
#  ('.', 'PROPN', '.'),
#  ('future', 'NOUN', 'future'),
#  ('data', 'NOUN', 'datum'),
#  ('ownership', 'NOUN', 'ownership'),
#  ('control', 'NOUN', 'control'),
#  ('example', 'NOUN', 'example'),
#  ('emergent', 'ADJ', 'emergent'),
#  ('movement', 'NOUN', 'movement'),
#  ('poised', 'VERB', 'poise'),
#  ('replace', 'VERB', 'replace'),
#  ('outdated', 'ADJ', 'outdated'),
#  ('incumbent', 'ADJ', 'incumbent'),
#  ('system', 'NOUN', 'system'),
#  ('ActionRealising', 'PROPN', 'ActionRealising'),
#  ('emergent', 'ADJ', 'emergent'),
#  ('movement', 'NOUN', 'movement'),
#  ('wo', 'AUX', 'will'),
#  ('happen', 'VERB', 'happen'),
#  ('requires', 'VERB', 'require'),
#  ('support', 'NOUN', 'support'),
#  ('people', 'NOUN', 'people'),
#  ('leading', 'VERB', 'lead'),
#  ('reform', 'NOUN', 'reform'),
#  ('researchers', 'NOUN', 'researcher'),
#  ('inventors', 'NOUN', 'inventor'),
#  ('advocates', 'NOUN', 'advocate'),
#  ('amplify', 'VERB', 'amplify'),
#  ('promote', 'VERB', 'promote'),
#  ('positive', 'ADJ', 'positive'),
#  ('use', 'NOUN', 'use'),
#  ('cases', 'NOUN', 'case'),
#  ('work', 'VERB', 'work'),
#  ('shift', 'VERB', 'shift'),
#  ('collective', 'ADJ', 'collective'),
#  ('mindset', 'NOUN', 'mindset'),
#  ('global', 'ADJ', 'global'),
#  ('citizens', 'NOUN', 'citizen'),
#  ('Web', 'PROPN', 'Web'),
#  ('Foundation', 'PROPN', 'Foundation'),
#  ('co', 'VERB', 'co'),
#  ('-', 'VERB', '-'),
#  ('founded', 'VERB', 'found'),
#  ('Rosemary', 'PROPN', 'Rosemary'),
#  ('Leith', 'PROPN', 'Leith'),
#  ('continue', 'VERB', 'continue'),
#  ('support', 'VERB', 'support'),
#  ('accelerate', 'VERB', 'accelerate'),
#  ('emergent', 'ADJ', 'emergent'),
#  ('system', 'NOUN', 'system'),
#  ('people', 'NOUN', 'people'),
#  ('need', 'NOUN', 'need'),
#  ('urgent', 'ADJ', 'urgent'),
#  ('need', 'NOUN', 'need'),
#  ('morally', 'ADV', 'morally'),
#  ('courageous', 'ADJ', 'courageous'),
#  ('leadership', 'NOUN', 'leadership'),
#  ('rising', 'VERB', 'rise'),
#  ('collectivise', 'VERB', 'collectivise'),
#  ('solutions', 'NOUN', 'solution'),
#  ('overturn', 'VERB', 'overturn'),
#  ('online', 'ADJ', 'online'),
#  ('world', 'NOUN', 'world'),
#  ('dictated', 'VERB', 'dictate'),
#  ('profit', 'NOUN', 'profit'),
#  ('dictated', 'VERB', 'dictate'),
#  ('needs', 'NOUN', 'need'),
#  ('humanity', 'NOUN', 'humanity'),
#  ('online', 'ADJ', 'online'),
#  ('ecosystem', 'NOUN', 'ecosystem'),
#  ('live', 'VERB', 'live'),
#  ('reach', 'VERB', 'reach'),
#  ('potential', 'NOUN', 'potential'),
#  ('provide', 'VERB', 'provide'),
#  ('foundations', 'NOUN', 'foundation'),
#  ('creativity', 'NOUN', 'creativity'),
#  ('collaboration', 'NOUN', 'collaboration'),
#  ('compassion', 'NOUN', 'compassion'),
#  ('Tim', 'PROPN', 'Tim'),
#  ('Berners', 'PROPN', 'Berners'),
#  ('Lee12th', 'PROPN', 'Lee12th'),
#  ('March', 'PROPN', 'March'),
#  ('2024', 'NUM', '2024'),
#  ('---151FollowWritten', 'VERB', '---151FollowWritten'),
#  ('Tim', 'PROPN', 'Tim'),
#  ('Berners', 'PROPN', 'Berners'),
#  ('Lee55', 'PROPN', 'Lee55'),
#  ('K', 'PROPN', 'K'),
#  ('FollowersInventor', 'PROPN', 'FollowersInventor'),
#  ('WWW', 'PROPN', 'WWW'),
#  ('Co', 'NOUN', 'co'),
#  ('-', 'NOUN', '-'),
#  ('founder', 'NOUN', 'founder'),
#  ('/', 'SYM', '/'),
#  ('CTO', 'PROPN', 'CTO'),
#  ('Inrupt.com', 'PROPN', 'Inrupt.com'),
#  ('|', 'VERB', '|'),
#  ('Lead', 'PROPN', 'Lead'),
#  ('Solidproject.org', 'PROPN', 'Solidproject.org'),
#  ('|', 'PROPN', '|'),
#  ('Co', 'PROPN', 'Co'),
#  ('-', 'NOUN', '-'),
#  ('founder', 'NOUN', 'founder'),
#  ('WebFoundation.org', 'X', 'webfoundation.org'),
#  ('theODI.org', 'PROPN', 'theODI.org'),
#  ('Founder', 'PROPN', 'Founder'),
#  ('W3C.org', 'PROPN', 'W3C.org'),
#  ('Emeritus', 'PROPN', 'Emeritus'),
#  ('Prof', 'PROPN', 'Prof'),
#  ('CS', 'PROPN', 'CS'),
#  ('MIT', 'PROPN', 'MIT'),
#  ('&', 'CCONJ', '&'),
#  ('OxfordFollowHelpStatusAboutCareersBlogPrivacyTermsText',
#   'NOUN',
#   'oxfordfollowhelpstatusaboutcareersblogprivacytermstext'),
#  ('speechTeams', 'NUM', 'speechteams')]

# %% [markdown]
# ## Sentence dependency tree

# %%
displacy.render(nlp(str(sentences1[10])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8621e7ab860c425aacd4024f7495a218-0" class="displacy" width="410" height="197.0" direction="ltr" style="max-width: none; height: 197.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">”</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">Pay</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="107.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">attention:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8621e7ab860c425aacd4024f7495a218-0-0" stroke-width="2px" d="M70,62.0 C70,2.0 170.0,2.0 170.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8621e7ab860c425aacd4024f7495a218-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,64.0 L62,52.0 78,52.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8621e7ab860c425aacd4024f7495a218-0-1" stroke-width="2px" d="M190,62.0 C190,2.0 290.0,2.0 290.0,62.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8621e7ab860c425aacd4024f7495a218-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290.0,64.0 L298.0,52.0 282.0,52.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
displacy.render(nlp(str(sentences2[20])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e2f17b336ee54f50a480717880f16b95-0" class="displacy" width="3890" height="437.0" direction="ltr" style="max-width: none; height: 437.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Level</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">SetTo</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">truly</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">transform</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">current</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">system,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">must</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">simultaneously</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">tackle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">its</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">existing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">problems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">champion</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">efforts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2330">those</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2330">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">visionary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">individuals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2810">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2810">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="2930">actively</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2930">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">working</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3170">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3170">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3290">build</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3290">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3410">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3530">new,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3530">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="347.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">improved</tspan>
#     <tspan class="displacy-tag" dy="2em"

# %% [markdown]
# # NER in french

# %%
! python -m spacy download fr_core_news_sm
# Out:
# Collecting fr-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-3.7.0/fr_core_news_sm-3.7.0-py3-none-any.whl (16.3 MB)
#      ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#       --------------------------------------- 0.2/16.3 MB 2.9 MB/s eta 0:00:06
#      - -------------------------------------- 0.7/16.3 MB 5.4 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/16.3 MB 7.2 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.9/16.3 MB 8.7 MB/s eta 0:00:02
#      ------ --------------------------------- 2.7/16.3 MB 10.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.7/16.3 MB 12.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 4.7/16.3 MB 13.2 MB/s eta 0:00:01
#      -------------- ------------------------- 6.0/16.3 MB 14.8 MB/s eta 0:00:01
#      ------------------ --------------------- 7.4/16.3 MB 16.4 MB/s eta 0:00:01
#      -------------------- ------------------- 8.1/16.3 MB 16.3 MB/s eta 0:00:01
#      ---------------------- ----------------- 9.0/16.3 MB 16.5 MB/s eta 0:00:01
#      ------------------------ -------------- 10.2/16.3 MB 17.2 MB/s eta 0:00:01
#      --------------------------- ----------- 11.4/16.3 MB 21.8 MB/s eta 0:00:01
#      ------------------------------ -------- 12.8/16.3 MB 23.4 MB/s eta 0:00:01
#      --------------------------------- ----- 14.2/16.3 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------  15.9/16.3 MB 26.2 MB/s eta 0:00:01
#      --------------------------------------- 16.3/16.3 MB 24.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\rohit\anaconda3\lib\site-packages (from fr-core-news-sm==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\rohit\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\rohit\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohit\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\rohit\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\rohit\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: colorama in c:\users\rohit\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\rohit\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\rohit\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rohit\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->fr-core-news-sm==3.7.0) (2.1.1)
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-3.7.0
# [+] Download and installation successful
# You can now load the package via spacy.load('fr_core_news_sm')

# %%
nlp = spacy.load("fr_core_news_sm")

# %%
link3 = url_to_string('https://www.lefigaro.fr/')
article3 = nlp(link3)
len(article3.ents)
# Out:
# 551

# %%
displacy.render(article3, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">                                                                                                                                                                                                                         Le Figaro - Actualité en direct et informations en continu
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  au contenu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Menu VENTE FLASH 4,49€/mois pendant 12
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moisRechercherNouveauLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Cuisine5000 recettes exclusivesRubriques et services du FigaroJO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris 2024PolitiqueInternationalSociétéVoxÉconomieSportCultureVoyageStyleMadameVinLe FigaroRubriques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et services du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FigaroLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  LiveLe Figaro MagazineLa
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VérificationLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ÉtudiantFaits diversSantéSciencesFig
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataTech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     webBourseLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ImmobilierEmploiArt de vivreAutomobileLangue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  françaiseGolfHistoireTVMagProgramme
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TVMaison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JardinLe FigaroscopeJeuxCarnet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  du jourGuide achatServicesBilletteriePodcastsLa question du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jourLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     StoreLes Voyages FÀ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  savoir en
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FranceNos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  journaux et magazinesLes sites du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groupe FigaroSe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  connecterFermer le panneauOuvrir le
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     panneauMon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  compte
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mon espace personnelMes newslettersMes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  commentairesS'abonnerAide et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contactSe déconnecterLire le journal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VENTE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  FLASH 4,49€/mois pendant 12 mois
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Éditions localesRadio &amp; PodcastsTV &amp; VidéosNewslettersBordeauxLyonMarseilleNantesNice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# Publicité

# %%
labels3 = [x.label_ for x in article3.ents]
Counter(labels3)
# Out:
# Counter({'LOC': 163, 'MISC': 145, 'ORG': 125, 'PER': 118})

# %%
items = [x.text for x in article3.ents]
Counter(items).most_common(5)
# Out:
# [('l’', 34), ('s’', 9), ('d’', 7), ('Ukraine', 6), ('Le Figaro', 6)]

# %%
sentences3 = [x for x in article3.sents]
print(sentences3)
# Out:
# [                                                                                                                                                                                                                         , Le Figaro, - Actualité en direct et informations en continu                                                                            , Aller au contenu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              , Menu, VENTE, FLASH, 4,49€/mois, pendant 12 moisRechercherNouveauLe Figaro Cuisine5000 recettes exclusivesRubriques et services du FigaroJO Paris 2024PolitiqueInternationalSociétéVoxÉconomieSportCultureVoyageStyleMadameVinLe FigaroRubriques et services du FigaroLe Figaro, LiveLe Figaro MagazineLa VérificationLe Figaro ÉtudiantFaits diversSantéSciencesFig DataTech et webBourseLe Figaro ImmobilierEmploiArt de vivreAutomobileLangue françaiseGolfHistoireTVMagProgramme, TVMaison et JardinLe FigaroscopeJeuxCarnet du jourGuide achatServicesBilletteriePodcastsLa, question du jourLe Figaro, StoreLes Voyages FÀ savoir en FranceNos journaux et magazinesLes, sites du Groupe FigaroSe connecterFermer le panneauOuvrir le panneauMon compte, Mon espace personnelMes newslettersMes commentairesS'abonnerAide et contactSe déconnecterLire le journal VENTE, FLASH, 4,49€/mois pendant 12 mois Éditions localesRadio & PodcastsTV & VidéosNewslettersBordeauxLyonMarseilleNantesNice                                                                                                                                                                                                                                                                                                                                                        , Publicité                                                                                                                                                                                                                                                                                                                             Dette, déficits: vent de panique au sommet de l’État                                                                                                                                                                                       DÉCRYPTAGE, - Emmanuel Macron a convoqué mercredi à l’Élysée les responsables de la majorité pour un dîner consacré à la situation alarmante des finances publiques, avant le verdict des agences de notation fin avril.                                                                                                                                                                                                                                                    , Finances publiques :, Emmanuel, Macron invite mercredi soir les chefs de la majorité à l’Élysée                                                                                                                                                                                                                                                                                                                        , La charge de la dette sera très bientôt la première dépense du budget de l’État                                                                                                                                                                                                                                                                      ...

# %%
displacy.render(nlp(str(sentences3)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[                                                                                                                                                                                                                         ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Le Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , - Actualité en direct et informations en continu                                                                            ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  au contenu                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Menu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VENTE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FLASH
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , 4,49€/mois, pendant 12
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     moisRechercherNouveauLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Cuisine5000 recettes exclusivesRubriques et services du FigaroJO
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris 2024PolitiqueInternationalSociétéVoxÉconomieSportCultureVoyageStyleMadameVinLe FigaroRubriques
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et services du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FigaroLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     LiveLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  MagazineLa
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VérificationLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ÉtudiantFaits diversSantéSciencesFig
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     DataTech
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     webBourseLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ImmobilierEmploiArt de vivreAutomobileLangue françaiseGolfHistoireTVMagProgramme
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TVMaison
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  et
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JardinLe FigaroscopeJeuxCarnet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  du jourGuide achatServicesBilletteriePodcastsLa, question du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jourLe Figaro
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     StoreLes Voyages FÀ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  savoir en
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FranceNos
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  journaux et magazinesLes, sites du
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Groupe FigaroSe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  connecterFermer le panneauOuvrir le
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     panneauMon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  compte,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mon espace personnelMes newslettersMes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  commentairesS'abonnerAide et
# <mark class="entity" style="background: #

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y 
                                      for y
                                      in nlp(str(sentences3)) 
                                      if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('                                                                                                                                                                                                                        ',
#   'SPACE',
#   '                                                                                                                                                                                                                        '),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('Actualité', 'NOUN', 'actualité'),
#  ('direct', 'NOUN', 'direct'),
#  ('informations', 'NOUN', 'information'),
#  ('continu', 'NOUN', 'continu'),
#  ('                                                                           ',
#   'SPACE',
#   '                                                                           '),
#  ('Aller', 'VERB', 'aller'),
#  ('contenu', 'NOUN', 'contenu'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             '),
#  ('Menu', 'PROPN', 'Menu'),
#  ('VENTE', 'ADJ', 'vent'),
#  ('FLASH', 'PROPN', 'FLASH'),
#  ('4,49€/mois', 'NUM', '4,49€/mois'),
#  ('12', 'NUM', '12'),
#  ('moisRechercherNouveauLe', 'ADP', 'moisrecherchernouveaule'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('Cuisine5000', 'NOUN', 'cuisine5000'),
#  ('recettes', 'NOUN', 'recette'),
#  ('exclusivesRubriques', 'ADJ', 'exclusivesrubrique'),
#  ('services', 'NOUN', 'service'),
#  ('FigaroJO', 'PROPN', 'FigaroJO'),
#  ('Paris', 'PROPN', 'Paris'),
#  ('2024PolitiqueInternationalSociétéVoxÉconomieSportCultureVoyageStyleMadameVinLe',
#   'NOUN',
#   '2024politiqueinternationalsociétévoxéconomiesportculturevoyagestylemadamevinle'),
#  ('FigaroRubriques', 'ADJ', 'figarorubrique'),
#  ('services', 'NOUN', 'service'),
#  ('FigaroLe', 'PROPN', 'FigaroLe'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('LiveLe', 'NOUN', 'livele'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('MagazineLa', 'NOUN', 'magazinela'),
#  ('VérificationLe', 'PROPN', 'VérificationLe'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('ÉtudiantFaits', 'NOUN', 'étudiantfait'),
#  ('diversSantéSciencesFig', 'ADJ', 'diverssantésciencesfig'),
#  ('DataTech', 'NOUN', 'datatech'),
#  ('webBourseLe', 'PROPN', 'webBourseLe'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('ImmobilierEmploiArt', 'NUM', 'ImmobilierEmploiArt'),
#  ('vivreAutomobileLangue', 'NOUN', 'vivreautomobilelangue'),
#  ('françaiseGolfHistoireTVMagProgramme',
#   'NOUN',
#   'françaisegolfhistoiretvmagprogramme'),
#  ('TVMaison', 'PROPN', 'TVMaison'),
#  ('JardinLe', 'NOUN', 'jardinle'),
#  ('FigaroscopeJeuxCarnet', 'ADJ', 'figaroscopejeuxcarnet'),
#  ('jourGuide', 'ADJ', 'jourguid'),
#  ('achatServicesBilletteriePodcastsLa',
#   'NOUN',
#   'achatservicesbilletteriepodcastsla'),
#  ('question', 'NOUN', 'question'),
#  ('jourLe', 'NOUN', 'jourle'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('StoreLes', 'NOUN', 'storele'),
#  ('Voyages', 'PROPN', 'Voyages'),
#  ('FÀ', 'AUX', 'fà'),
#  ('savoir', 'VERB', 'savoir'),
#  ('FranceNos', 'NOUN', 'franceno'),
#  ('journaux', 'ADJ', 'journal'),
#  ('magazinesLes', 'VERB', 'magazinesler'),
#  ('sites', 'NOUN', 'site'),
#  ('Groupe', 'NOUN', 'groupe'),
#  ('FigaroSe', 'ADJ', 'figaros'),
#  ('connecterFermer', 'VERB', 'connecterfermer'),
#  ('panneauOuvrir', 'NOUN', 'panneauouvrir'),
#  ('panneauMon', 'ADJ', 'panneaumon'),
#  ('compte', 'NOUN', 'compte'),
#  ('espace', 'PROPN', 'espace'),
#  ('newslettersMes', 'NOUN', 'newslettersme'),
#  ("commentairesS'", 'ADJ', "commentairess'"),
#  ('abonnerAide', 'NOUN', 'abonneraide'),
#  ('contactSe', 'PROPN', 'contactSe'),
#  ('déconnecterLire', 'ADJ', 'déconnecterlir'),
#  ('journal', 'NOUN', 'journal'),
#  ('VENTE', 'ADJ', 'vent'),
#  ('FLASH', 'PROPN', 'FLASH'),
#  ('4,49€/mois', 'NUM', '4,49€/mois'),
#  ('12', 'NUM', '12'),
#  ('mois', 'NOUN', 'mois'),
#  ('Éditions', 'NOUN', 'édition'),
#  ('localesRadio', 'PRON', 'localesradio'),
#  ('&', 'CCONJ', 'et'),
#  ('PodcastsTV', 'NOUN', 'podcaststv'),
#  ('&', 'CCONJ', 'et'),
#  ('VidéosNewslettersBordeauxLyonMarseilleNantesNice',
#   'NOUN',
#   'vidéosnewslettersbordeauxlyonmarseillenantesnice'),
#  ('                                                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                       '),
#  ('Publicité', 'NOUN', 'publicité'),
#  ('                                                                                                                                                                                                                                                                                                                            ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                            '),
#  ('Dette', 'PROPN', 'Dette'),
#  ('déficits', 'ADJ', 'déficit'),
#  ('vent', 'ADV', 'vent'),
#  ('panique', 'VERB', 'panique'),
#  ('sommet', 'NOUN', 'sommet'),
#  ('État', 'NOUN', 'état'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('DÉCRYPTAGE', 'NOUN', 'décryptage'),
#  ('Emmanuel', 'PROPN', 'Emmanuel'),
#  ('Macron', 'NOUN', 'macron'),
#  ('convoqué', 'VERB', 'convoquer'),
#  ('mercredi', 'NOUN', 'mercredi'),
#  ('Élysée', 'PROPN', 'Élysée'),
#  ('responsables', 'NOUN', 'responsable'),
#  ('majorité', 'NOUN', 'majorité'),
#  ('dîner', 'NOUN', 'dîner'),
#  ('consacré', 'VERB', 'consacrer'),
#  ('situation', 'NOUN', 'situation'),
#  ('alarmante', 'ADJ', 'alarmant'),
#  ('finances', 'NOUN', 'finance'),
#  ('publiques', 'ADJ', 'public'),
#  ('verdict', 'NOUN', 'verdict'),
#  ('agences', 'NOUN', 'agence'),
#  ('notation', 'NOUN', 'notation'),
#  ('fin', 'NOUN', 'fin'),
#  ('avril', 'NOUN', 'avril'),
#  ('                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                   '),
#  ('Finances', 'NOUN', 'finance'),
#  ('publiques', 'ADJ', 'public'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('Emmanuel', 'PROPN', 'Emmanuel'),
#  ('Macron', 'NOUN', 'macron'),
#  ('invite', 'ADJ', 'invit'),
#  ('mercredi', 'NOUN', 'mercredi'),
#  ('soir', 'NOUN', 'soir'),
#  ('chefs', 'NOUN', 'chef'),
#  ('majorité', 'NOUN', 'majorité'),
#  ('Élysée', 'PROPN', 'Élysée'),
#  ('                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                       '),
#  ('charge', 'NOUN', 'charge'),
#  ('dette', 'NOUN', 'dette'),
#  ('bientôt', 'ADV', 'bientôt'),
#  ('dépense', 'NOUN', 'dépense'),
#  ('budget', 'NOUN', 'budget'),
#  ('État', 'NOUN', 'état'),
#  ('                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                       '),
#  ('ÉDITORIAL', 'NOUN', 'éditorial'),
#  ('FIGARO', 'PROPN', 'FIGARO'),
#  ('Dette', 'PROPN', 'Dette'),
#  ('déficits', 'ADJ', 'déficit'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('«', 'NOUN', '«'),
#  ('France', 'PROPN', 'France'),
#  ('toboggan', 'NOUN', 'toboggan'),
#  ('enfer', 'NOUN', 'enfer'),
#  ('                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                  '),
#  ('Publié', 'VERB', 'publier'),
#  ('39', 'NUM', '39'),
#  ('min', 'NOUN', 'min'),
#  ('                                                                                                                                                                                                                                                                        ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                        '),
#  ('Faut', 'PROPN', 'Faut'),
#  ('-il', 'PRON', 'il'),
#  ('couper', 'VERB', 'couper'),
#  ('dépenses', 'NOUN', 'dépense'),
#  ('sociales', 'ADJ', 'social'),
#  ('réduire', 'VERB', 'réduire'),
#  ('déficits', 'ADJ', 'déficit'),
#  ('publics', 'ADJ', 'public'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                           '),
#  ('Oui', 'PROPN', 'Oui'),
#  ('                                                                                  ',
#   'SPACE',
#   '                                                                                  '),
#  ('Non', 'ADV', 'non'),
#  ('                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                   '),
#  ('Oui', 'PROPN', 'Oui'),
#  ('                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                       '),
#  ('Non', 'ADV', 'non'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                             '),
#  ('homme', 'NOUN', 'homme'),
#  ('«', 'ADJ', '«'),
#  ('acquis', 'VERB', 'acquérir'),
#  ('idéologie', 'NOUN', 'idéologie'),
#  ('djihadiste', 'ADJ', 'djihadist'),
#  ('mis', 'VERB', 'mettre'),
#  ('examen', 'NOUN', 'examen'),
#  ('projet', 'NOUN', 'projet'),
#  ('attaque', 'VERB', 'attaquer'),
#  ('contre', 'ADP', 'contre'),
#  ('édifice', 'NOUN', 'édifice'),
#  ('religieux', 'ADJ', 'religieux'),
#  ('                                                                                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                   '),
#  ('sympathisant', 'VERB', 'sympathiser'),
#  ('État', 'NOUN', 'état'),
#  ('islamique', 'ADJ', 'islamique'),
#  ('sexagénaire', 'ADJ', 'sexagénaire'),
#  ('projeté', 'VERB', 'projeter'),
#  ('attentat', 'NOUN', 'attentat'),
#  ('contre', 'ADP', 'contre'),
#  ('église', 'NOUN', 'église'),
#  ('été', 'AUX', 'être'),
#  ('interpellé', 'VERB', 'interpeller'),
#  ('région', 'NOUN', 'région'),
#  ('parisienne', 'ADJ', 'parisien'),
#  ('                                                                                                    ',
#   'SPACE',
#   '                                                                                                    '),
#  ('Publié', 'VERB', 'publier'),
#  ('32', 'NUM', '32'),
#  ('min', 'NOUN', 'min'),
#  ('                                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                       '),
#  ('Publicité', 'NOUN', 'publicité'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('Marseille', 'NOUN', 'marseille'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('lendemain', 'NOUN', 'lendemain'),
#  ('venue', 'NOUN', 'venue'),
#  ('Macron', 'NOUN', 'macron'),
#  ('trafiquants', 'NOUN', 'trafiquant'),
#  ('drogue', 'ADJ', 'drogu'),
#  ('Castellane', 'PROPN', 'Castellane'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('24', 'NUM', '24'),
#  ('heures', 'NOUN', 'heure'),
#  ('déploiement', 'NOUN', 'déploiement'),
#  ('centaines', 'NOUN', 'centaine'),
#  ('policiers', 'NOUN', 'policier'),
#  ('faire', 'AUX', 'faire'),
#  ('déguerpir', 'ADJ', 'déguerpir'),
#  ('dealers', 'NOUN', 'dealer'),
#  ('allées', 'NOUN', 'allée'),
#  ('cité', 'NOUN', 'cité'),
#  ('marseillaise', 'VERB', 'marseillais'),
#  ('revenir', 'VERB', 'revenir'),
#  ('catimini', 'NOUN', 'catimini'),
#  ('reprendre', 'VERB', 'reprendre'),
#  ('juteux', 'NOUN', 'juteux'),
#  ('trafic', 'NOUN', 'trafic'),
#  ('                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                   '),
#  ('opération', 'NOUN', 'opération'),
#  ('«', 'ADJ', '«'),
#  ('place', 'NOUN', 'place'),
#  ('nette', 'ADJ', 'net'),
#  ('Marseille', 'PROPN', 'Marseille'),
#  ('réveille', 'VERB', 'réveiller'),
#  ('tension', 'NOUN', 'tension'),
#  ('Éric', 'PROPN', 'Éric'),
#  ('Dupond', 'PROPN', 'Dupond'),
#  ('-', 'PROPN', '-'),
#  ('Moretti', 'PROPN', 'Moretti'),
#  ('magistrats', 'NOUN', 'magistrat'),
#  ('                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                       '),
#  ('«', 'NOUN', '«'),
#  ('aller', 'VERB', 'aller'),
#  ('gare', 'NOUN', 'gare'),
#  ('Marseille-Saint-Charles', 'NOUN', 'marseille-saint-charle'),
#  ('squats', 'NOUN', 'squat'),
#  ('migrants', 'NOUN', 'migrant'),
#  ('recruter', 'VERB', 'recruter'),
#  ('jeunes', 'NOUN', 'jeune'),
#  ('dealers', 'ADJ', 'dealer'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '),
#  ('Européennes', 'X', 'Européennes'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('Macronie', 'NOUN', 'macronie'),
#  ('RN', 'PROPN', 'RN'),
#  ('épinglent', 'VERB', 'épingler'),
#  ('LR', 'NOUN', 'lr'),
#  ('affiche', 'NOUN', 'affiche'),
#  ('montrant', 'VERB', 'montrer'),
#  ('général', 'NOUN', 'général'),
#  ('Gomart', 'PROPN', 'Gomart'),
#  ('uniforme', 'PROPN', 'uniforme'),
#  ('                                                                                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                   '),
#  ('Accusés', 'PROPN', 'Accusés'),
#  ('adversaires', 'NOUN', 'adversaire'),
#  ('enfreint', 'VERB', 'enfreindre'),
#  ('Code', 'NOUN', 'code'),
#  ('électoral', 'ADJ', 'électoral'),
#  ('Républicains', 'NOUN', 'républicain'),
#  ('défendent', 'VERB', 'défendre'),
#  ('distinguo', 'NOUN', 'distinguo'),
#  ('communications', 'NOUN', 'communication'),
#  ('X', 'NOUN', 'x'),
#  ('propagande', 'ADJ', 'propagand'),
#  ('officielle', 'ADJ', 'officiel'),
#  ('                                                                                                    ',
#   'SPACE',
#   '                                                                                                    '),
#  ('Publié', 'VERB', 'publier'),
#  ('2', 'NUM', '2'),
#  ('heures', 'NOUN', 'heure'),
#  ('                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                       '),
#  ('armée', 'NOUN', 'armée'),
#  ('française', 'ADJ', 'français'),
#  ('veut', 'VERB', 'vouloir'),
#  ('renforcer', 'VERB', 'renforcer'),
#  ('dissuasion', 'NOUN', 'dissuasion'),
#  ('conventionnelle', 'ADJ', 'conventionnel'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('DÉCRYPTAGE', 'NOUN', 'décryptage'),
#  ('tribune', 'NOUN', 'tribune'),
#  ('propos', 'NOUN', 'propos'),
#  ('général', 'NOUN', 'général'),
#  ('Schill', 'PROPN', 'Schill'),
#  ('chef', 'NOUN', 'chef'),
#  ('état', 'NOUN', 'état'),
#  ('-', 'NOUN', '-'),
#  ('major', 'NOUN', 'major'),
#  ('armée', 'NOUN', 'armée'),
#  ('terre', 'NOUN', 'terre'),
#  ('résonnent', 'VERB', 'résonner'),
#  ('déclarations', 'NOUN', 'déclaration'),
#  ('d‘Emmanuel', 'PRON', 'd‘emmanuel'),
#  ('Macron', 'NOUN', 'macron'),
#  ('excluant', 'VERB', 'exclure'),
#  ('envoi', 'NOUN', 'envoi'),
#  ('soldats', 'NOUN', 'soldat'),
#  ('Ukraine', 'PROPN', 'Ukraine'),
#  ('chiffre', 'NOUN', 'chiffre'),
#  ('20.000', 'NUM', '20.000'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('hommes', 'NOUN', 'homme'),
#  ('évoqué', 'VERB', 'évoquer'),
#  ('                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                   '),
#  ('Européens', 'NOUN', 'européen'),
#  ('préparent', 'VERB', 'préparer'),
#  ('augmenter', 'VERB', 'augmenter'),
#  ('soutien', 'NOUN', 'soutien'),
#  ('Ukraine', 'PROPN', 'Ukraine'),
#  ('doper', 'VERB', 'doper'),
#  ('propre', 'ADJ', 'propre'),
#  ('défense', 'NOUN', 'défense'),
#  ('                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                  '),
#  ('Publié', 'VERB', 'publier'),
#  ('2', 'NUM', '2'),
#  ('heures', 'NOUN', 'heure'),
#  ('                                                                                                                                                                                                                                                                                               ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                               '),
#  ('Guerre', 'NOUN', 'guerre'),
#  ('Ukraine', 'PROPN', 'Ukraine'),
#  ('Kiev', 'PROPN', 'Kiev'),
#  ('reçu', 'VERB', 'recevoir'),
#  ('aide', 'NOUN', 'aide'),
#  ('4,5', 'NUM', '4,5'),
#  ('milliards', 'NOUN', 'milliard'),
#  ('euros', 'NOUN', 'euro'),
#  ('Union', 'PROPN', 'Union'),
#  ('européenne', 'ADJ', 'européen'),
#  ('                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                       '),
#  ('Guerre', 'NOUN', 'guerre'),
#  ('Ukraine', 'PROPN', 'Ukraine'),
#  ('financier', 'ADJ', 'financier'),
#  ('Kiev', 'PROPN', 'Kiev'),
#  ('UE', 'PROPN', 'UE'),
#  ('souhaite', 'VERB', 'souhaiter'),
#  ('utiliser', 'VERB', 'utiliser'),
#  ('avoirs', 'NOUN', 'avoir'),
#  ('gelés', 'ADJ', 'gelé'),
#  ('Banque', 'NOUN', 'banque'),
#  ('centrale', 'ADJ', 'central'),
#  ('russe', 'ADJ', 'russe'),
#  ('                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                  '),
#  ('Publié', 'VERB', 'publier'),
#  ('2', 'NUM', '2'),
#  ('heures', 'NOUN', 'heure'),
#  ('                                                                                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                  '),
#  ('Piscines', 'ADJ', 'piscine'),
#  ('non', 'ADV', 'non'),
#  ('déclarées', 'VERB', 'déclarer'),
#  ('allocations', 'NOUN', 'allocation'),
#  ('familiales', 'ADJ', 'familial'),
#  ('faux', 'ADJ', 'faux'),
#  ('arrêts', 'NOUN', 'arrêt'),
#  ('travail', 'NOUN', 'travail'),
#  ('chiffres', 'NOUN', 'chiffre'),
#  ('spectaculaires', 'ADJ', 'spectaculaire'),
#  ('fraude', 'NOUN', 'fraude'),
#  ('fiscale', 'ADJ', 'fiscal'),
#  ('sociale', 'ADJ', 'social'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('ministre', 'NOUN', 'ministre'),
#  ('Gabriel', 'PROPN', 'Gabriel'),
#  ('Attal', 'PROPN', 'Attal'),
#  ('présenté', 'VERB', 'présenter'),
#  ('mercredi', 'NOUN', 'mercredi'),
#  ('bilan', 'NOUN', 'bilan'),
#  ('2023', 'NUM', '2023'),
#  ('plan', 'NOUN', 'plan'),
#  ('lutte', 'NOUN', 'lutte'),
#  ('gouvernement', 'NOUN', 'gouvernement'),
#  ('contre', 'ADP', 'contre'),
#  ('fraudes', 'NOUN', 'fraude'),
#  ('fiscale', 'ADJ', 'fiscal'),
#  ('sociale', 'ADJ', 'social'),
#  ('chiffres', 'NOUN', 'chiffre'),
#  ('-clés', 'ADJ', '-clé'),
#  ('retenir', 'VERB', 'retenir'),
#  ('                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                   '),
#  ('gouvernement', 'NOUN', 'gouvernement'),
#  ('compte', 'NOUN', 'compte'),
#  ('milliards', 'NOUN', 'milliard'),
#  ('lutte', 'NOUN', 'lutte'),
#  ('contre', 'ADP', 'contre'),
#  ('fraude', 'NOUN', 'fraude'),
#  ('fiscale', 'ADJ', 'fiscal'),
#  ('sociale', 'ADJ', 'social'),
#  ('                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                  '),
#  ('Publié', 'VERB', 'publier'),
#  ('1', 'NUM', '1'),
#  ('heure', 'NOUN', 'heure'),
#  ('                                                                                                                                                             ',
#   'SPACE',
#   '                                                                                                                                                             '),
#  ('sélection', 'NOUN', 'sélection'),
#  ('rédactionNos', 'NOUN', 'rédactionno'),
#  ('10', 'NUM', '10'),
#  ('hôtels', 'NOUN', 'hôtel'),
#  ('Relais', 'PROPN', 'Relais'),
#  ('&', 'CCONJ', 'et'),
#  ('Châteaux', 'PROPN', 'Châteaux'),
#  ('préférés', 'VERB', 'préférer'),
#  ('200', 'NUM', '200'),
#  ('€', 'NOUN', 'euro'),
#  ('nuit', 'NOUN', 'nuit'),
#  ('travers', 'NOUN', 'travers'),
#  ('Europe', 'PROPN', 'Europe'),
#  ('                                                                                                                         ',
#   'SPACE',
#   '                                                                                                                         '),
#  ('Mbappé', 'PROPN', 'Mbappé'),
#  ('-', 'PROPN', '-'),
#  ('Benzema', 'PROPN', 'Benzema'),
#  ('JO', 'PROPN', 'JO'),
#  ('clash', 'NOUN', 'clash'),
#  ('Deschamps', 'ADV', 'deschamps'),
#  ('-', 'PROPN', '-'),
#  ('DTN', 'PROPN', 'DTN'),
#  ('porte', 'VERB', 'porte'),
#  ('fermée', 'ADJ', 'fermé'),
#  ('Zidane', 'PROPN', 'Zidane'),
#  ('vérités', 'NOUN', 'vérité'),
#  ('président', 'NOUN', 'président'),
#  ('FFF', 'PROPN', 'FFF'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('ENTRETIEN', 'NOUN', 'entretien'),
#  ('EXCLUSIF', 'ADV', 'exclusif'),
#  ('Philippe', 'PROPN', 'Philippe'),
#  ('Diallo', 'PROPN', 'Diallo'),
#  ('longuement', 'ADV', 'longuement'),
#  ('balayé', 'VERB', 'balayer'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('dossiers', 'NOUN', 'dossier'),
#  ('chauds', 'ADJ', 'chaud'),
#  ('football', 'NOUN', 'football'),
#  ('français', 'ADJ', 'français'),
#  ('prenant', 'NOUN', 'prenant'),
#  ('position', 'NOUN', 'position'),
#  ('                                                                                                                                                                        ',
#   'SPACE',
#   '                                                                                                                                                                        '),
#  ('amende', 'NOUN', 'amende'),
#  ('Donald', 'NOUN', 'donald'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('-elle', 'PRON', 'lui'),
#  ('inéligible', 'ADJ', 'inéligible'),
#  ('payait', 'VERB', 'payer'),
#  ('                                                                                                                                                                                      ',
#   'SPACE',
#   '                                                                                                                                                                                      '),
#  ('Condamné', 'VERB', 'condamner'),
#  ('acquitter', 'VERB', 'acquitter'),
#  ('amende', 'NOUN', 'amende'),
#  ('454', 'NUM', '454'),
#  ('millions', 'NOUN', 'million'),
#  ('dollars', 'NOUN', 'dollar'),
#  ('fraudes', 'NOUN', 'fraude'),
#  ('ancien', 'ADJ', 'ancien'),
#  ('président', 'NOUN', 'président'),
#  ('américain', 'ADJ', 'américain'),
#  ('incapable', 'ADJ', 'incapable'),
#  ('apporter', 'VERB', 'apporter'),
#  ('justice', 'NOUN', 'justice'),
#  ('new-yorkaise', 'PROPN', 'new-yorkais'),
#  ('garantie', 'NOUN', 'garantie'),
#  ('paiement', 'NOUN', 'paiement'),
#  ('avocats', 'NOUN', 'avocat'),
#  ('                                                                                                                                                                                                                                                   ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                   '),
#  ('70', 'NUM', '70'),
#  ('%', 'NOUN', 'pourcent'),
#  ('Américains', 'NOUN', 'américain'),
#  ('président', 'NOUN', 'président'),
#  ('devrait', 'VERB', 'devoir'),
#  ('abri', 'NOUN', 'abri'),
#  ('poursuites', 'NOUN', 'poursuite'),
#  ('pénales', 'ADJ', 'pénal'),
#  ('crimes', 'NOUN', 'crime'),
#  ('commis', 'VERB', 'commettre'),
#  ('mandat', 'NOUN', 'mandat'),
#  ('                                                                                                                                                                                                                                                                                                                       ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                       '),
#  ('États-Unis', 'PROPN', 'États-Unis'),
#  ('justice', 'NOUN', 'justice'),
#  ('menace', 'VERB', 'menacer'),
#  ('fortune', 'NOUN', 'fortune'),
#  ('empire', 'ADJ', 'empire'),
#  ('immobilier', 'VERB', 'immobilier'),
#  ('Donald', 'NOUN', 'donald'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              '),
#  ('plan', 'NOUN', 'plan'),
#  ('bataille', 'NOUN', 'bataille'),
#  ('aéroport', 'NOUN', 'aéroport'),
#  ('Paris', 'PROPN', 'Paris'),
#  ('-', 'PROPN', '-'),
#  ('Charles', 'PROPN', 'Charles'),
#  ('-', 'PROPN', '-'),
#  ('-', 'PROPN', '-'),
#  ('Gaulle', 'PROPN', 'Gaulle'),
#  ('JO', 'NOUN', 'jo'),
#  ('                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                           '),
#  ('EXCLUSIF', 'NOUN', 'exclusif'),
#  ('plateforme', 'NOUN', 'plateforme'),
#  ('groupe', 'NOUN', 'groupe'),
#  ('ADP', 'PROPN', 'ADP'),
#  ('métamorphoser', 'VERB', 'métamorphoser'),
#  ('accueillir', 'VERB', 'accueillir'),
#  ('52.000', 'NUM', '52.000'),
#  ('accrédités', 'NOUN', 'accrédité'),
#  ('délégations', 'NOUN', 'délégation'),
#  ('officielles', 'ADJ', 'officiel'),
#  ('ajouteront', 'VERB', 'ajouter'),
#  ('flux', 'NOUN', 'flux'),
#  ('classique', 'ADJ', 'classique'),
#  ('passagers', 'NOUN', 'passager'),
#  ('été', 'VERB', 'être'),
#  ('défi', 'NOUN', 'défi'),
#  ('logistique', 'ADJ', 'logistique'),
#  ('sécuritaire', 'ADJ', 'sécuritaire'),
#  ('majeur', 'ADJ', 'majeur'),
#  ('                                                                                                    ',
#   'SPACE',
#   '                                                                                                    '),
#  ('Publié', 'VERB', 'publier'),
#  ('2', 'NUM', '2'),
#  ('heures', 'NOUN', 'heure'),
#  ('                                                                                                                                                                                                                                                                                  ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                  '),
#  ('rendez-vous', 'NOUN', 'rendez-vous'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             '),
#  ('Normandie', 'NOUN', 'normandie'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('investir', 'VERB', 'investir'),
#  ('résidence', 'NOUN', 'résidence'),
#  ('secondaire', 'ADJ', 'secondaire'),
#  ('plage', 'NOUN', 'plage'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('palmarès', 'ADV', 'palmarès'),
#  ('exclusif', 'ADV', 'exclusif'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('«', 'NOUN', '«'),
#  ('Business', 'PROPN', 'Business'),
#  ('classe', 'NOUN', 'classe'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('codes', 'NOUN', 'code'),
#  ('intemporels', 'ADJ', 'intemporel'),
#  ('dépendent', 'VERB', 'dépendre'),
#  ('élégance', 'NOUN', 'élégance'),
#  ('réussite', 'NOUN', 'réussite'),
#  ('professionnelle', 'ADJ', 'professionnel'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('«', 'ADJ', '«'),
#  ('village', 'NOUN', 'village'),
#  ('souillarde', 'NOUN', 'souillarde'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('père', 'NOUN', 'père'),
#  ('fils', 'NOUN', 'fils'),
#  ('impossible', 'ADJ', 'impossible'),
#  ('transmission', 'NOUN', 'transmission'),
#  ('maison', 'NOUN', 'maison'),
#  ('famille', 'NOUN', 'famille'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('cuvées', 'NOUN', 'cuvée'),
#  ('amateur', 'NOUN', 'amateur'),
#  ('grands', 'ADJ', 'grand'),
#  ('vins', 'NOUN', 'vin'),
#  ('blancs', 'ADJ', 'blanc'),
#  ('devrait', 'VERB', 'devoir'),
#  ('miser', 'VERB', 'miser'),
#  ('30', 'NUM', '30'),
#  ('euros', 'NOUN', 'euro'),
# ...
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                '),
#  ('«', 'NOUN', '«'),
#  ('structure', 'NOUN', 'structure'),
#  ('points', 'NOUN', 'point'),
#  ('juteux', 'NOUN', 'juteux'),
#  ('Nantes', 'PROPN', 'Nantes'),
#  ('tombée', 'ADJ', 'tomber'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('7', 'NUM', '7'),
#  ('individus', 'NOUN', 'individu'),
#  ('incarcérés', 'VERB', 'incarcérer'),
#  ('importante', 'ADJ', 'important'),
#  ('opération', 'NOUN', 'opération'),
#  ('antidrogue', 'VERB', 'antidrogue'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('Marseille', 'PROPN', 'Marseille'),
#  ('collège', 'NOUN', 'collège'),
#  ('terrorisé', 'VERB', 'terroriser'),
#  ('élève', 'NOUN', 'élève'),
#  ('exclu', 'ADJ', 'exclure'),
#  ('établissement', 'NOUN', 'établissement'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('Nice', 'NOUN', 'nice'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('doigts', 'NOUN', 'doigt'),
#  ('statue', 'NOUN', 'statue'),
#  ('Jacques', 'PROPN', 'Jacques'),
#  ('Chirac', 'PROPN', 'Chirac'),
#  ('nouvelle', 'ADJ', 'nouveau'),
#  ('fois', 'NOUN', 'fois'),
#  ('sectionnés', 'VERB', 'sectionner'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           '),
#  ('Marineland', 'PROPN', 'Marineland'),
#  ('Antibes', 'PROPN', 'Antibes'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('polémique', 'NOUN', 'polémique'),
#  ('départ', 'NOUN', 'départ'),
#  ('précipité', 'NOUN', 'précipité'),
#  ('orques', 'NOUN', 'orque'),
#  ('spectacles', 'NOUN', 'spectacle'),
#  ('reprendre', 'VERB', 'reprendre'),
#  ('                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ',
#   'SPACE',
#   '                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          '),
#  ('sélectionÀ', 'NOUN', 'sélectionà'),
#  ('UneLe', 'NOUN', 'unele'),
#  ('flash', 'ADJ', 'flash'),
#  ('                                                                                     ',
#   'SPACE',
#   '                                                                                     '),
#  ('vidéos', 'NOUN', 'vidéo'),
#  ('jour', 'NOUN', 'jour'),
#  ('                                                             ',
#   'SPACE',
#   '                                                             '),
#  ('voir', 'VERB', 'voir'),
#  ('                        ', 'SPACE', '                        '),
#  ('Gaza', 'PROPN', 'Gaza'),
#  ('Hamas', 'PROPN', 'Hamas'),
#  ('juge', 'VERB', 'juger'),
#  ('réponse', 'NOUN', 'réponse'),
#  ('Israël', 'NOUN', 'israël'),
#  ('«', 'ADJ', '«'),
#  ('extrêmement', 'ADV', 'extrêmement'),
#  ('négative»«Comme', 'ADP', 'négative»«comme'),
#  ('dur', 'ADJ', 'dur'),
#  ('Gaulle', 'PROPN', 'Gaulle'),
#  ('Gaulle', 'PROPN', 'Gaulle'),
#  ('Emmanuel', 'PROPN', 'Emmanuel'),
#  ('Macron', 'NOUN', 'macron'),
#  ('hommage', 'NOUN', 'hommage'),
#  ('fils', 'NOUN', 'fils'),
#  ('GénéralHuit', 'NOUN', 'généralhuit'),
#  ('morts', 'NOUN', 'mort'),
#  ('naufrage', 'NOUN', 'naufrage'),
#  ('navire', 'ADJ', 'navir'),
#  ('sud-coréen', 'NOUN', 'sud-coréen'),
#  ('large', 'NOUN', 'large'),
#  ('JaponBusiness', 'NOUN', 'japonbusines'),
#  ('Story', 'PROPN', 'Story'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('rencontre', 'NOUN', 'rencontre'),
#  ('Charlotte', 'NOUN', 'charlotte'),
#  ('Alaux', 'PROPN', 'Alaux'),
#  ('cofondatrice', 'NOUN', 'cofondatrice'),
#  ('OMNI', 'NOUN', 'omni'),
#  ('                                ',
#   'SPACE',
#   '                                '),
#  ('Voir', 'VERB', 'voir'),
#  ('                            ', 'SPACE', '                            '),
#  ('Agnès', 'PROPN', 'Agnès'),
#  ('Verdier', 'PROPN', 'Verdier'),
#  ('-', 'PROPN', '-'),
#  ('Molinié', 'PROPN', 'Molinié'),
#  ('«', 'NOUN', '«'),
#  ('France', 'PROPN', 'France'),
#  ('opposer', 'VERB', 'opposer'),
#  ('objectifs', 'NOUN', 'objectif'),
#  ('délirants', 'ADJ', 'délirant'),
#  ('Bruxelles', 'PROPN', 'Bruxelles'),
#  ('matière', 'NOUN', 'matière'),
#  ('énergies', 'NOUN', 'énergie'),
#  ('renouvelables»TRIBUNE', 'ADJ', 'renouvelables»tribun'),
#  ('objectif', 'NOUN', 'objectif'),
#  ('fixé', 'VERB', 'fixer'),
#  ('Commission', 'NOUN', 'commission'),
#  ('européenne', 'ADJ', 'européen'),
#  ('atteindre', 'VERB', 'atteindre'),
#  ('44', 'NUM', '44'),
#  ('%', 'NOUN', 'pourcent'),
#  ('énergies', 'NOUN', 'énergie'),
#  ('renouvelables', 'ADJ', 'renouvelable'),
#  ('ici', 'ADV', 'ici'),
#  ('2030', 'NUM', '2030'),
#  ('apparaît', 'VERB', 'apparaître'),
#  ('irréaliste', 'ADJ', 'irréaliste'),
#  ('éloigné', 'VERB', 'éloigner'),
#  ('intérêts', 'NOUN', 'intérêt'),
#  ('économiques', 'ADJ', 'économique'),
#  ('écologiques', 'ADJ', 'écologique'),
#  ('analyse', 'NOUN', 'analyse'),
#  ('directrice', 'NOUN', 'directrice'),
#  ('iFrap', 'ADJ', 'ifrap'),
#  ('préconise', 'VERB', 'préconiser'),
#  ('électricité', 'NOUN', 'électricité'),
#  ('nucléaire', 'ADJ', 'nucléaire'),
#  ('reconnue', 'VERB', 'reconnaître'),
#  ('énergie', 'NOUN', 'énergie'),
#  ('renouvelable', 'ADJ', 'renouvelable'),
#  ('niveau', 'NOUN', 'niveau'),
#  ('européen', 'ADJ', 'européen'),
#  ('            ', 'SPACE', '            '),
#  ('Publié', 'VERB', 'publier'),
#  ('2', 'NUM', '2'),
#  ('heures', 'NOUN', 'heure'),
#  ('        ', 'SPACE', '        '),
#  ('hommes', 'NOUN', 'homme'),
#  ('pratiquant', 'VERB', 'pratiquer'),
#  ('«', 'NOUN', '«'),
#  ('chemsex', 'ADJ', 'chemsex'),
#  ('retrouvés', 'NOUN', 'retrouvé'),
#  ('morts', 'ADJ', 'mort'),
#  ('Bordeaux', 'PROPN', 'Bordeaux'),
#  ('individu', 'NOUN', 'individu'),
#  ('placé', 'VERB', 'placer'),
#  ('détentionDeux', 'NUM', 'détentionDeux'),
#  ('quadragénaires', 'ADJ', 'quadragénaire'),
#  ('décédés', 'VERB', 'décéder'),
#  ('12', 'NUM', '12'),
#  ('mars', 'NOUN', 'mars'),
#  ('Bordeaux', 'PROPN', 'Bordeaux'),
#  ('probablement', 'ADV', 'probablement'),
#  ('rapports', 'NOUN', 'rapport'),
#  ('sexuels', 'ADJ', 'sexuel'),
#  ('influence', 'NOUN', 'influence'),
#  ('drogues', 'NOUN', 'drogue'),
#  ('homme', 'NOUN', 'homme'),
#  ('40', 'NUM', '40'),
#  ('ans', 'NOUN', 'an'),
#  ('été', 'AUX', 'être'),
#  ('placé', 'VERB', 'placer'),
#  ('détention', 'NOUN', 'détention'),
#  ('provisoire', 'ADJ', 'provisoire'),
#  ('reconnu', 'VERB', 'reconnaître'),
#  ('organisation', 'NOUN', 'organisation'),
#  ('soirées', 'NOUN', 'soirée'),
#  ('«', 'PROPN', '«'),
#  ('chemsex', 'ADJ', 'chemsex'),
#  ('Bordeaux', 'PROPN', 'Bordeaux'),
#  ('apprenti', 'ADJ', 'apprenti'),
#  ('chimiste', 'ADJ', 'chimist'),
#  ('multinationales', 'ADJ', 'multinational'),
#  ('crime', 'NOUN', 'crime'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('France', 'PROPN', 'France'),
#  ('inondée', 'VERB', 'inonder'),
#  ('drogues', 'NOUN', 'drogue'),
#  ('synthèseMort', 'NOUN', 'synthèsemort'),
#  ('Laetitia', 'PROPN', 'Laetitia'),
#  ('Krupa', 'PROPN', 'Krupa'),
#  ('ancienne', 'ADJ', 'ancien'),
#  ('chroniqueuse', 'NOUN', 'chroniqueuse'),
#  ('Médias', 'PROPN', 'Médias'),
#  ('Mag', 'NOUN', 'mag'),
#  ('France', 'PROPN', 'France'),
#  ('5', 'NUM', '5'),
#  ('    ', 'SPACE', '    '),
#  ('société', 'NOUN', 'société'),
#  ('production', 'NOUN', 'production'),
#  ('Jaraprod', 'PROPN', 'Jaraprod'),
#  ('annoncé', 'VERB', 'annoncer'),
#  ('décès', 'NOUN', 'décès'),
#  ('journaliste', 'NOUN', 'journaliste'),
#  ('médias', 'NOUN', 'média'),
#  ('politique', 'ADJ', 'politique'),
#  ('mercredi', 'NOUN', 'mercredi'),
#  ('20', 'NUM', '20'),
#  ('mars', 'NOUN', 'mars'),
#  ('                ', 'SPACE', '                '),
#  ('Regarder', 'VERB', 'regarder'),
#  ('vidéo', 'NOUN', 'vidéo'),
#  ('                             ', 'SPACE', '                             '),
#  ('Programme', 'PROPN', 'Programme'),
#  ('TV', 'ADP', 'tv'),
#  ('soir', 'NOUN', 'soir'),
#  ('                                                             ',
#   'SPACE',
#   '                                                             '),
#  ('voir', 'VERB', 'voir'),
#  ('                        ', 'SPACE', '                        '),
#  ('Doc', 'PROPN', 'Doc'),
#  ('Saison', 'PROPN', 'Saison'),
#  ('3', 'NUM', '3'),
#  ('TF1', 'NOUN', 'tf1'),
#  ('21h10Narco', 'NUM', '21h10Narco'),
#  ('Circus', 'PROPN', 'Circus'),
#  ('Saison', 'PROPN', 'Saison'),
#  ('1', 'PRON', '1'),
#  ('Canal+', 'NOUN', 'canal+'),
#  ('21hTop', 'NUM', '21hTop'),
#  ('chef', 'NOUN', 'chef'),
#  ('M6', 'NOUN', 'm6'),
#  ('21h10La', 'NUM', '21h10La'),
#  ('turbulence', 'NOUN', 'turbulence'),
#  ('Rodin', 'PROPN', 'Rodin'),
#  ('Figaro', 'PROPN', 'Figaro'),
#  ('TV', 'PROPN', 'TV'),
#  ('IdF', 'VERB', 'idf'),
#  ('21h', 'ADJ', '21h'),
#  ('                                ',
#   'SPACE',
#   '                                '),
#  ('Voir', 'VERB', 'voir'),
#  ('                            ', 'SPACE', '                            '),
#  ('Européennes', 'PROPN', 'Européennes'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('Emmanuel', 'PROPN', 'Emmanuel'),
#  ('Macron', 'NOUN', 'macron'),
#  ('convoque', 'VERB', 'convoquer'),
#  ('troupes', 'NOUN', 'troupe'),
#  ('Élysée', 'PROPN', 'Élysée'),
#  ('plancher', 'VERB', 'plancher'),
#  ('listeINFO', 'NOUN', 'listeinfo'),
#  ('FIGARO', 'PROPN', 'FIGARO'),
#  ('chef', 'NOUN', 'chef'),
#  ('État', 'NOUN', 'état'),
#  ('réunit', 'NOUN', 'réunit'),
#  ('dirigeants', 'NOUN', 'dirigeant'),
#  ('parti', 'NOUN', 'parti'),
#  ('Renaissance', 'PROPN', 'Renaissance'),
#  ('mercredi', 'NOUN', 'mercredi'),
#  ('soir', 'NOUN', 'soir'),
#  ('préciser', 'VERB', 'préciser'),
#  ('dispositif', 'NOUN', 'dispositif'),
#  ('vue', 'NOUN', 'vue'),
#  ('scrutin', 'NOUN', 'scrutin'),
#  ('9', 'NUM', '9'),
#  ('juin', 'NOUN', 'juin'),
#  ('Ratification', 'NOUN', 'ratification'),
#  ('Ceta', 'NOUN', 'ceta'),
#  ('\xa0', 'SPACE', '\xa0'),
#  ('Français', 'NOUN', 'français'),
#  ('majoritairement', 'ADV', 'majoritairement'),
#  ('hostiles', 'NOUN', 'hostile'),
#  ('accord', 'NOUN', 'accord'),
#  ('commercialSONDAGE', 'ADJ', 'commercialsondag'),
#  ...]

# %%
displacy.render(nlp(str(sentences3[10])), style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="fr" id="6f61e957ffb543a2a136acd208e29fba-0" class="displacy" width="890" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">TVMaison</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">et</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">JardinLe</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">FigaroscopeJeuxCarnet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">du</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">jourGuide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">achatServicesBilletteriePodcastsLa</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-0" stroke-width="2px" d="M190,182.0 C190,122.0 280.0,122.0 280.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M190,184.0 L182,172.0 198,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-1" stroke-width="2px" d="M70,182.0 C70,62.0 285.0,62.0 285.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M285.0,184.0 L293.0,172.0 277.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-2" stroke-width="2px" d="M310,182.0 C310,122.0 400.0,122.0 400.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">flat:name</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,184.0 L408.0,172.0 392.0,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-3" stroke-width="2px" d="M550,182.0 C550,122.0 640.0,122.0 640.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M550,184.0 L542,172.0 558,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-4" stroke-width="2px" d="M670,182.0 C670,122.0 760.0,122.0 760.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,184.0 L662,172.0 678,172.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6f61e957ffb543a2a136acd208e29fba-0-5" stroke-width="2px" d="M70,182.0 C70,2.0 770.0,2.0 770.0,182.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6f61e957ffb543a2a136acd208e29fba-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770.0,184.0 L778.0,172.0 762.0,172.0" fill="currentColor"/>
# </g>
# </svg></span>
